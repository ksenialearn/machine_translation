# %%
import numpy as np
from collections import Counter
import pickle as pkl
import random
import pdb
import pandas as pd
import string
import re
import unicodedata
import os
import time
import math

import spacy
from spacy.lang.en.stop_words import STOP_WORDS

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torch.utils.data import Dataset
from torch.autograd import Variable
from torch.nn import functional

import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
# %matplotlib inline

#specify SOS() and EOS(end of sentence)
#specify maximum vocabulary size = 50000
PAD_IDX = 2
UNK_IDX = 3
SOS_token = 0
EOS_token = 1
MAX_VOCAB_SIZE = 50000
MAX_LENGTH = 30

train_en = '/data/train.tok.en'
train_zh = '/data/train.tok.zh'
val_en = '/data/dev.tok.en'
val_zh = '/data/dev.tok.zh'

# %%
#user GPU if possible
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if device.type == "cuda":
    print("Currently using GPU")

# %%
folder_path = os.getcwd()

# %% [markdown]
# Load Pre-Trained Embedding Matrix

# %%
def load_emb_matrix(language):
    #load fasttext word vectors
    words_to_load = MAX_VOCAB_SIZE
    if language == 'english':
        file = 'wiki-news-300d-1M-subword.vec'
    if language == 'chinese':
        file = 'cc.zh.300.vec'
    

    with open(folder_path + 'data/' + file) as f:
        #remove the first line
        firstLine = f.readline()
        loaded_embeddings = np.zeros((words_to_load + 4, 300))
        words2id = {}
        idx2words = {}
        #ordered_words = []
        for i, line in enumerate(f):
            if i >= words_to_load: 
                break
            s = line.split()
            loaded_embeddings[i + 4 , :] = np.asarray(s[1:])
            words2id['<SOS>'] = SOS_token
            words2id['<EOS>'] = EOS_token
            words2id['<pad>'] = PAD_IDX
            words2id['<unk>'] = UNK_IDX
            words2id[s[0]] = i + 4
            
            idx2words[0] = '<SOS>'
            idx2words[1] = '<EOD>'
            idx2words[2] = '<pad>'
            idx2words[3] = '<unk>'
            
            idx2words[i + 4] = s[0]
   

    return words2id,idx2words,loaded_embeddings

# %%
def generate_weights_matrix(idx2words,loaded_embeddings):
   
    matrix_len = len(idx2words)
    weights_matrix = np.zeros((matrix_len, 300))
    
    for key in idx2words.keys():
        try: 
            weights_matrix[key] = loaded_embeddings[key]
        except KeyError:
            weights_matrix[key] = np.random.normal(scale=0.6, size=(emb_dim, ))
    return weights_matrix

# %%
words2id_eng,idx2words_eng,loaded_embeddings_eng = load_emb_matrix('english')
words2id_zh,idx2words_zh,loaded_embeddings_zh = load_emb_matrix('chinese')

pkl.dump(words2id_eng, open(folder_path + 'data/words2id_eng.pkl', 'wb'))
pkl.dump(idx2words_eng, open(folder_path +'data/idx2words_eng.pkl', 'wb'))
pkl.dump(loaded_embeddings_eng, open(folder_path +'data/embedding_matrix_eng.pkl', 'wb'))

pkl.dump(words2id_zh, open(folder_path + 'data/words2id_zh.pkl', 'wb'))
pkl.dump(idx2words_zh, open(folder_path + 'data/idx2words_zh.pkl', 'wb'))
pkl.dump(loaded_embeddings_zh, open(folder_path +'data/embedding_matrix_zh.pkl', 'wb'))

# %%
weights_matrix_eng = generate_weights_matrix(idx2words_eng,loaded_embeddings_eng)
pkl.dump(weights_matrix_eng, open(folder_path + 'data/weights_matrix_eng.pkl', 'wb'))
weights_matrix_eng = torch.from_numpy(weights_matrix_eng).to(device)

weights_matrix_zh = generate_weights_matrix(idx2words_zh,loaded_embeddings_zh)
pkl.dump(weights_matrix_zh, open(folder_path + 'data/weights_matrix_zh.pkl', 'wb'))
weights_matrix_zh = torch.from_numpy(weights_matrix_zh).to(device)

# %%
words2id_eng = pkl.load(open(folder_path + "/data/words2id_eng.pkl", "rb"))
idx2words_eng = pkl.load(open(folder_path +"/data/idx2words_eng.pkl", "rb"))
loaded_embeddings_eng = pkl.load(open(folder_path +"/data/embedding_matrix_eng.pkl", "rb"))
words2id_zh = pkl.load(open(folder_path + "/data/words2id_zh.pkl", "rb"))
idx2words_zh = pkl.load(open(folder_path +"/data/idx2words_zh.pkl", "rb"))
loaded_embeddings_zh = pkl.load(open(folder_path +"/data/embedding_matrix_zh.pkl", "rb"))

weights_matrix_eng = pkl.load(open(folder_path +"/data/weights_matrix_eng.pkl", "rb"))
weights_matrix_eng = torch.from_numpy(weights_matrix_eng).to(device)
weights_matrix_zh = pkl.load(open(folder_path +"/data/weights_matrix_zh.pkl", "rb"))
weights_matrix_zh = torch.from_numpy(weights_matrix_zh).to(device)

# %% [markdown]
# Read Languages

# %%
#define a class of language
class Language:
    def __init__(self, name,word2index,index2word):
        self.name = name
        self.word2index = word2index
        #self.word2count = {}
        self.index2word = index2word
        self.n_words = len(word2index)

# %%
# Turn a Unicode string to plain ASCII, thanks to
# http://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters

def normalizeString(s):
    s = s.replace(r"&quot;","")
    s = s.replace(r"&apos;","'")
    s = unicodeToAscii(s.strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s
  

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
#To read the data file we will split the file into lines, and then split lines into pairs. 

def readLanguages(input_lang,target_lang):
    print("\nReading lines...")

    # Read the file and split into lines
    input_lines = open(folder_path + input_lang, encoding='utf-8').\
        read().strip().split('\n')
    target_lines = open(folder_path + target_lang, encoding='utf-8').\
        read().strip().split('\n')

    # Split every line and normalize
    #for chinese input, strip the space at the begining and end of the sentence
    #for english output, use normalizeString function
    input_lines_norm = [l.strip() for l in input_lines]
    target_lines_norm = [normalizeString(l) for l in target_lines]
    
    #build pairs
    #drop pair if both zh and en are empty strings
    pairs = [[item[0],item[1]] for item in zip(input_lines_norm,target_lines_norm) if len(item[0])+len(item[1]) != 0]
    
    input_lines = Language("zh",words2id_zh,idx2words_zh)
    target_lines = Language("en",words2id_eng,idx2words_eng)

    return input_lines, target_lines, pairs

# %%
def prepareData(input_lang, target_lang):
    input_lang, output_lang, pairs = readLanguages(input_lang, target_lang)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
#     for pair in pairs:
#         input_lang.addSentence(pair[0])
#         output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    
    return input_lang, output_lang, pairs

# %% [markdown]
# Preparing Data
# ========

# %%
train_input_lang, train_output_lang, train_pairs = prepareData(train_zh, train_en)
print("print a random pair of training pairs:")
print(random.choice(train_pairs))



val_input_lang, val_output_lang, val_pairs = prepareData(val_zh, val_en)
print("print a random pair of validation pairs:")
print(random.choice(val_pairs))


# pkl.dump(train_input, open(folder_path +'data/train_input.pkl', 'wb'))
# pkl.dump(train_output, open(folder_path +'data/train_output.pkl', 'wb'))
# pkl.dump(train_pairs, open(folder_path +'data/train_pairs.pkl', 'wb'))
# pkl.dump(val_input, open(folder_path +'data/val_input.pkl', 'wb'))
# pkl.dump(val_output, open(folder_path +'data/val_output.pkl', 'wb'))
# pkl.dump(val_pairs, open(folder_path +'data/val_pairs.pkl', 'wb'))
# Out:
# Reading lines...
# Read 213237 sentence pairs
# Trimmed to 156070 sentence pairs
# Counting words...
# Counted words:
# zh 50004
# en 50004
# print a random pair of training pairs:
# ['这 是 第一 第一个 一个 演示', 'Here s the first demonstration .']
#
# Reading lines...
# Read 1261 sentence pairs
# Trimmed to 848 sentence pairs
# Counting words...
# Counted words:
# zh 50004
# en 50004
# print a random pair of validation pairs:
# ['同时   沥青 沥青路 会 产生 很大 噪音', 'Also asphalt can create a lot of noise .']

# %% [markdown]
# ## Build DataLoader for minibatch

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] if word in lang.word2index else UNK_IDX for word in sentence.split(' ')] + [EOS_token]

# %%
BATCH_SIZE = 32

class VocabDataset(Dataset):
    """
    Note that this class inherits torch.utils.data.Dataset
    """

    def __init__(self, pairs,input_language, output_language):
        """
        @param pairs: pairs of input and target sentences(raw text sentences)
        @param input_language: Class Lang of input languages (zh in this case)
        @param output_language: Class Lang of output languages (en in this case)

        """
        self.pairs = pairs
        self.inputs = [pair[0] for pair in pairs]
        self.input_lang = input_language
        self.output_lang = output_language
        self.outputs = [pair[1] for pair in pairs]
        
        
        #assert self.input_lang == self.target_lang
       
    def __len__(self):
         return len(self.pairs)

    def __getitem__(self, key):
        """
        Triggered when you call dataset[i]
        """
        
        #turn raw text sentecens into indices
        input_ = indexesFromSentence(self.input_lang, self.inputs[key])
        output = indexesFromSentence(self.output_lang, self.outputs[key])
        
        #print both the length of the source sequence and the target sequence
        return [input_,len(input_),output,len(output)]
    
    
    def __gettext__(self,key):
        return [self.inputs[key],self.outputs[key]]

def vocab_collate_func(batch):
    """
    Customized function for DataLoader that dynamically pads the batch so that all
    data have the same length
    """
    input_data_list = []
    output_data_list = []
   
    
    for datum in batch:
        input_data_list.append(datum[0])
        output_data_list.append(datum[2])
      
      
    # Zip into pairs, sort by length (descending), unzip
    seq_pairs = sorted(zip(input_data_list, output_data_list), key=lambda p: len(p[0]), reverse=True)
    input_seqs, output_seqs = zip(*seq_pairs)
    
    #store the length of the sequences 
    input_data_len = [len(p) for p in input_seqs]
    output_data_len = [len(p) for p in output_seqs]
    
    #padding
    padded_vec_input = [np.pad(np.array(p),
                                 pad_width=((0,MAX_LENGTH-len(p))),
                                 mode="constant", constant_values=0) for p in input_seqs]
        
    padded_vec_output = [np.pad(np.array(p),
                                 pad_width=((0,MAX_LENGTH-len(p))),
                                 mode="constant", constant_values=0) for p in output_seqs]      
    
    
    input_var = Variable(torch.LongTensor(padded_vec_input))
    output_var = Variable(torch.LongTensor(padded_vec_output))
    input_data_len = Variable(torch.LongTensor(input_data_len))
    output_data_len = Variable(torch.LongTensor(output_data_len))
    
    
    return [input_var,input_data_len,output_var,output_data_len]

# %%
# Build train and valid dataloaders

train_dataset = VocabDataset(train_pairs,train_input_lang, train_output_lang)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=BATCH_SIZE,
                                           collate_fn=vocab_collate_func,
                                           shuffle=True,
                                           drop_last = True)


val_dataset = VocabDataset(val_pairs,val_input_lang,val_output_lang)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                           batch_size=BATCH_SIZE,
                                           collate_fn=vocab_collate_func,
                                           shuffle=False,
                                         drop_last = True)

# %% [markdown]
# Building Neural Networks (Encoder & Decoder)
# -----------

# %% [markdown]
# The Encoder
# -----------
#
# The encoder of a seq2seq network is a RNN that outputs some value for
# every word from the input sentence. For every input word the encoder
# outputs a vector and a hidden state, and uses the hidden state for the
# next input word.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, weights_matrix, input_size, hidden_size,n_layers=1):
        super(EncoderRNN, self).__init__()
     
        
        self.hidden_size = hidden_size
        self.input_size = input_size
        self.n_layers = n_layers
        self.batch_size = BATCH_SIZE
        self.num_embeddings, self.embedding_dim = weights_matrix.size()
        
        self.embedding = nn.Embedding(self.num_embeddings, self.embedding_dim)
        self.embedding.weight.data.copy_(weights_matrix)
        self.embedding.weight.requires_grad = False

        
        self.gru = nn.GRU(self.embedding_dim, hidden_size, n_layers, bidirectional=True)
        

    def forward(self, input_seqs, input_len, hidden=None):

       
        embedded = self.embedding(input_seqs)
        packed = torch.nn.utils.rnn.pack_padded_sequence(embedded, input_len)
        output, hidden = self.gru(packed, hidden)

        output, output_len = torch.nn.utils.rnn.pad_packed_sequence(output)
        output = output[:, :, :self.hidden_size] + output[:, : ,self.hidden_size:]
        
        return output,hidden

# %%
class CNN(nn.Module):
    def __init__(self, weights_matrix, hidden_size, num_layers, kernel_size):

        super(CNN, self).__init__()

        num_embeddings, embedding_dim = weights_matrix.size()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim,padding_idx=PAD_IDX)
        self.embedding.weight.data.copy_(weights_matrix)
        self.embedding.weight.requires_grad = False
        
        #out: dim = []
        self.layer = nn.Sequential(
            nn.Conv1d(embedding_dim, hidden_size, kernel_size = kernel_size, padding=PAD_IDX),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size = (MAX_LENGTH - kernel_size + 1),padding = PAD_IDX))
        
        self.fc = nn.Linear(hidden_size, 180)
        
        self.layer = self.layer.to(device)
        self.fc = self.fc1.to(device)

        
        
    def forward(self, input_seq):
        # size: [batch_size,seq_length,hidden_size]
        embed = self.embedding(input_seq).to(device)
        #in: dim = [batch_size_x, hidden_size, seq_length_length](after transpose)
        #out: dim = []
        hidden = self.layer(embed.transpose(1,2))

        out = hidden.reshape(hidden.size(0), -1)
        out = self.fc(out)
        out = F.relu(out.contiguous().view(-1, out.size(-1)))

        
        return out,hidden

# %% [markdown]
# Decoder w/o Attention
# ------------------------
# In the simplest seq2seq decoder we use only last output of the encoder. This last output is sometimes called the context vector as it encodes context from the entire sequence. This context vector is used as the initial hidden state of the decoder.
#
# At every step of decoding, the decoder is given an input token and hidden state. The initial input token is the start-of-string <SOS> token, and the first hidden state is the context vector (the encoder's last hidden state).

# %%
class DecoderRNN(nn.Module):
    def __init__(self, weights_matrix, hidden_size, output_size,n_layers=1):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        #self.batch_size = BATCH_SIZE
        self.num_embeddings, self.embedding_dim = weights_matrix.size()
        
        #self.embedding = nn.Embedding(output_size, hidden_size)
        self.embedding = nn.Embedding(self.num_embeddings, self.embedding_dim)
        self.embedding.weight.data.copy_(weights_matrix)
        self.embedding.weight.requires_grad = False
        
        self.gru1 = nn.GRU(self.embedding_dim, hidden_size,n_layers)
        self.gru2 = nn.GRU(hidden_size, hidden_size,n_layers)
        
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input_seq, hidden):
        
        embedded = self.embedding(input_seq) # dim = Batch_Size x embedding_dim
        embedded = embedded.view(1, embedded.size(0), self.embedding_dim) # S=1 x Batch_Size x embedding_dim
        
        rnn_output, hidden = self.gru1(embedded, hidden)
        output = F.relu(rnn_output)
        
        output, hidden = self.gru2(output, hidden)
        output = self.softmax(self.out(output[0]))
        
        return output,hidden



    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size).to(device)

# %% [markdown]
# Attention Decoder
# ----------------
#
# If only the context vector is passed betweeen the encoder and decoder,
# that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to "focus" on a different part of
# the encoder's outputs for every step of the decoder's own outputs. First
# we calculate a set of *attention weights*. These will be multiplied by
# the encoder output vectors to create a weighted combination. The result
# (called ``attn_applied`` in the code) should contain information about
# that specific part of the input sequence, and thus help the decoder
# choose the right output words.
#
# Calculating the attention weights is done with another feed-forward
# layer ``attn``, using the decoder's input and hidden state as inputs.
# Because there are sentences of all sizes in the training data, to
# actually create and train this layer we have to choose a maximum
# sentence length (input length, for encoder outputs) that it can apply
# to. Sentences of the maximum length will use all the attention weights,
# while shorter sentences will only use the first few.

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, weights_matrix, hidden_size, output_size, n_layers=1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.max_length = max_length
        self.batch_size = BATCH_SIZE
        self.num_embeddings, self.embedding_dim = weights_matrix.size()

        #self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.embedding = nn.Embedding(self.num_embeddings, self.embedding_dim)
        self.embedding.weight.data.copy_(weights_matrix)
        self.embedding.weight.requires_grad = False
        
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
       
        self.gru1 = nn.GRU(self.embedding_dim, hidden_size,n_layers)
        self.gru2 = nn.GRU(hidden_size, hidden_size,n_layers)
        
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input_seq, hidden, encoder_outputs):
        embedded = self.embedding(input_seq).view(1, 1, -1)
 

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size).to(device)

# %%
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        
        self.method = method
        self.hidden_size = hidden_size
        
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)

        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(1, hidden_size))
     
    def forward(self, hidden, encoder_outputs):
        max_len = encoder_outputs.size(0)
        this_batch_size = encoder_outputs.size(1)

        # Create variable to store attention energies
        attn_energies = Variable(torch.zeros(this_batch_size, max_len)).to(device) # Batch_Size x Seq_Length

        
#         # For each batch of encoder outputs
        for b in range(this_batch_size):
            # Calculate energy for each encoder output
            for i in range(max_len):
                attn_energies[b, i] = self.score(hidden[:, b], encoder_outputs[i, b].unsqueeze(0))

        # Normalize energies to weights in range 0 to 1, resize to 1 x B x S
        return F.softmax(attn_energies,dim=1).unsqueeze(1)
      
    def score(self, hidden, encoder_output):
        
        if self.method == 'dot':
            energy = hidden.dot(encoder_output)
            return energy
        
        elif self.method == 'general':
            energy = self.attn(encoder_output)
            energy = torch.mm(hidden, energy.transpose(0,1))
            return energy
        
        elif self.method == 'concat':
            energy = self.attn(torch.cat((hidden, encoder_output), 1))
            energy = self.v.dot(energy)
            return energy

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, weights_matrix, hidden_size, output_size, n_layers=1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.batch_size = BATCH_SIZE
        self.num_embeddings, self.embedding_dim = weights_matrix.size()


        # Define layers
        #self.embedding = nn.Embedding(output_size, hidden_size)
        self.embedding = nn.Embedding(self.num_embeddings, self.embedding_dim)
        self.embedding.weight.data.copy_(weights_matrix)
        self.embedding.weight.requires_grad = False
        
        
        self.gru1 = nn.GRU(self.embedding_dim, hidden_size,n_layers)
        self.gru2 = nn.GRU(hidden_size, hidden_size,n_layers)
        
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        
        # Choose attention model
        if attn_model != 'none':
            self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_seq, last_hidden, encoder_outputs):
        # Note: we run this one step at a time

        # Get the embedding of the current input word (last output word)

        embedded = self.embedding(input_seq) # dim = Batch_Size x embedding_dim
        embedded = embedded.view(1, self.batch_size, self.embedding_dim) # S=1 x Batch_Size x embedding_dim

        # Get current hidden state from input word and last hidden state
        # rnn_output : [1 x batch_size x hidden_size]
        # hidden: [layer x batch_size x hidden_size]
        rnn_output, hidden = self.gru1(embedded, last_hidden)
        
        # Calculate attention from current RNN state and all encoder outputs;
        # apply to encoder outputs to get weighted average
        attn_weights = self.attn(rnn_output, encoder_outputs)
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1)) # B x S=1 x N

        # Attentional vector using the RNN hidden state and context vector
        # concatenated together (Luong eq. 5)
        rnn_output = rnn_output.squeeze(0) # S=1 x B x N -> B x N
        context = context.squeeze(1)       # B x S=1 x N -> B x N
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))

        # Finally predict next token (Luong eq. 6, without softmax)
        output = self.out(concat_output)

        #Return final output, hidden state, and attention weights (for visualization)
        return output, hidden, attn_weights
        #return attn_weights

# %%
class BahdanauAttnDecoderRNN(nn.Module):
    def __init__(self, weights_matrix, hidden_size, output_size, n_layers=1):
        super(BahdanauAttnDecoderRNN, self).__init__()
        
        # Define parameters
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.max_length = max_length
        self.batch_size = BATCH_SIZE
        self.num_embeddings, self.embedding_dim = weights_matrix.size()
        
        
        # Define layers
        #self.embedding = nn.Embedding(output_size, hidden_size)
        self.embedding = nn.Embedding(self.num_embeddings, self.embedding_dim)
        self.embedding.weight.data.copy_(weights_matrix)
        self.embedding.weight.requires_grad = False
        
        self.attn = Attn('concat', hidden_size)
        self.gru1 = nn.GRU(self.embedding_dim, hidden_size,n_layers)
        self.gru2 = nn.GRU(hidden_size, hidden_size,n_layers)
        self.out = nn.Linear(hidden_size, output_size)
    
    def forward(self, word_input, last_hidden, encoder_outputs):
        # Note: we run this one step at a time
        # TODO: FIX BATCHING
        
        # Get the embedding of the current input word (last output word)
        word_embedded = self.embedding(word_input).view(1, 1, -1) # S=1 x B x N
        
        # Calculate attention weights and apply to encoder outputs
        attn_weights = self.attn(last_hidden[-1], encoder_outputs)
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1)) # B x 1 x N
        context = context.transpose(0, 1) # 1 x B x N
        
        # Combine embedded input word and attended context, run through RNN
        rnn_input = torch.cat((word_embedded, context), 2)
        output, hidden = self.gru(rnn_input, last_hidden)
        
        # Final output layer
        output = output.squeeze(0) # B x N
        output = F.log_softmax(self.out(torch.cat((output, context), 1)),dim=1)
        
        # Return final output, hidden state, and attention weights (for visualization)
        return output, hidden, attn_weights

# %% [markdown]
# Training
# ========

# %%
#record the run time
def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def evaluate(encoder, decoder, sentence, input_lengths, translated, search='greedy', max_length=MAX_LENGTH):
    """
    Function that generate translation.
    First, feed the source sentence into the encoder and obtain the hidden states from encoder.
    Secondly, feed the hidden states into the decoder and unfold the outputs from the decoder.
    Lastly, for each outputs from the decoder, collect the corresponding words in the target language's vocabulary.
    And collect the attention for each output words.
    @param encoder: the encoder network
    @param decoder: the decoder network
    @param sentence: string, a sentence in source language to be translated
    @param max_length: the max # of words that the decoder can return
    @output decoded_words: a list of words in target language
    @output decoder_attentions: a list of vector, each of which sums up to 1.0
    """    
    # process input sentence
    with torch.no_grad():
        input_tensor = sentence.transpose(0,1).to(device)
        #input_length = sentence.size()[0]
        encoder_output, encoder_hidden = encoder(input_tensor, [lengths1[n].item()], None)

        decoder_input = Variable(torch.LongTensor([SOS_token])).to(device) # SOS
        decoder_hidden = encoder_hidden[:decoder.n_layers] # Use last (forward) hidden state from encoder 
        # output of this function
        decoded_words = ''

        for di in range(max_length):
            # for each time step, the decoder network takes two inputs: previous outputs and the previous hidden states
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden)
            
            # hint: print out decoder_output and decoder_attention
            # TODO: add your code here to populate decoded_words and decoder_attentions
            # TODO: do this in 2 ways discussed in class: greedy & beam_search
            
            # GREEDY
            topv, topi = decoder_output.data.topk(1) 

            if topi.item() == EOS_token:
                #decoded_words.append('<EOS>')
                break
            else:
                if topi.item() not in [SOS_token, EOS_token, UNK_IDX, PAD_IDX]:
                    decoded_words = decoded_words + ' ' + val_output_lang.index2word[topi.item()]
            
            decoder_input = topi[0].detach()
        
        translation = ''
        for i in translated: #expected translation
            if i.item() not in [SOS_token, EOS_token, UNK_IDX, PAD_IDX]:
                translation = translation + ' ' + val_output_lang.index2word[i.item()]

        return decoded_words, translation

# %%
def sequence_mask(sequence_length, max_len=None):
    if max_len is None:
        max_len = sequence_length.data.max()
    batch_size = BATCH_SIZE
    seq_range = torch.arange(0, max_len).long()
    seq_range_expand = seq_range.unsqueeze(0).expand(batch_size, max_len)
    seq_range_expand = Variable(seq_range_expand)
    
    seq_range_expand = seq_range_expand.to(device)
    seq_length_expand = (sequence_length.unsqueeze(1)
                         .expand_as(seq_range_expand))
    return seq_range_expand < seq_length_expand


def masked_cross_entropy(logits, target, length):
    length = Variable(torch.LongTensor(length)).to(device)

    """
    Args:
        logits: A Variable containing a FloatTensor of size
            (batch, max_len, num_classes) which contains the
            unnormalized probability for each class.
        target: A Variable containing a LongTensor of size
            (batch, max_len) which contains the index of the true
            class for each corresponding step.
        length: A Variable containing a LongTensor of size (batch,)
            which contains the length of each data in a batch.
    Returns:
        loss: An average loss value masked by the length.
    """
    
    # logits_flat: (batch * max_len, num_classes)
    logits_flat = logits.view(-1, logits.size(-1))
    # log_probs_flat: (batch * max_len, num_classes)
    log_probs_flat = F.log_softmax(logits_flat,dim=1)
    
    # target_flat: (batch * max_len, 1)
    target_flat = target.view(-1, 1)
    
    # losses_flat: (batch * max_len, 1)
    losses_flat = -torch.gather(log_probs_flat, dim=1, index=target_flat)
    # losses: (batch, max_len)
    losses = losses_flat.view(*target.size())
    # mask: (batch, max_len)
    mask = sequence_mask(sequence_length=length, max_len=target.size(1))
    losses = losses * mask.float()
    loss = losses.sum() / length.float().sum()
    return loss

# %% [markdown]
# ##Train Model

# %%
hidden_size = 500

encoder1 = EncoderRNN(weights_matrix_zh, train_input_lang.n_words, hidden_size,n_layers = 2).to(device)
#decoder1 = LuongAttnDecoderRNN('general', weights_matrix, hidden_size, train_output_lang_sample.n_words,n_layers = 2).to(device)
decoder1 = DecoderRNN(weights_matrix_eng, hidden_size, train_output_lang.n_words,n_layers = 2).to(device)

# %%
# encoder1 = EncoderRNN(train_input.n_words, hidden_size).to(device)
# decoder1 = DecoderRNN(hidden_size,train_output.n_words).to(device)
# encoder1.load_state_dict(torch.load(folder_path + "encoder1.pt"))
# decoder1.load_state_dict(torch.load(folder_path +"decoder1.pt"))

# %% [markdown]
# Testing small batches with teaching force

# %%
encoder_optimizer = optim.SGD(encoder1.parameters(), lr=0.1)
decoder_optimizer = optim.SGD(decoder1.parameters(), lr=0.1)
criterion = nn.NLLLoss()
teacher_forcing_ratio = 0.5
learning_rate = 0.0001

running_loss = 0
for i, (input_var,input_data_len,output_var,output_data_len) in enumerate(train_loader):
    input_batch = input_var.transpose(0,1).to(device)
    output_batch = output_var.transpose(0,1).to(device)

    loss = train(input_batch,input_data_len,output_batch,output_data_len, encoder1,
                 decoder1, encoder_optimizer, decoder_optimizer, criterion)
    print(loss)
    running_loss += loss

# %%
running_loss / len(train_loader.dataset)
# Out:
# 218.58528626361235

# %%
encoder_optimizer = optim.SGD(encoder1.parameters(), lr=0.1)
decoder_optimizer = optim.SGD(decoder1.parameters(), lr=0.1)
criterion = nn.NLLLoss()

for l, (input_var,input_data_len,output_var,output_data_len) in enumerate(train_loader):
    input_batch = input_var.transpose(0,1).to(device)
    output_batch = output_var.transpose(0,1).to(device)
    encoder_outputs, encoder_hidden = encoder1(input_batch, input_data_len, None)
  
    max_target_length = MAX_LENGTH
    # Prepare decoder input and outputs
    decoder_input = Variable(torch.LongTensor([SOS_token] * BATCH_SIZE)).to(device)
    decoder_hidden = encoder_hidden[:decoder1.n_layers] # Use last (forward) hidden state from encoder
    all_decoder_outputs = Variable(torch.zeros(max_target_length, BATCH_SIZE, decoder1.output_size)).to(device)
 
  
    # Run through decoder one time step at a time
    for t in range(max_target_length):
        decoder_output,decoder_hidden = decoder1(
        decoder_input, decoder_hidden
    )
        
        topv, topi = decoder_output.topk(1)
        decoder_input = topi.squeeze().detach()  # detach from history as input
        all_decoder_outputs[t] = decoder_output # Store this step's outputs
    
    # Test masked cross entropy loss
    loss = masked_cross_entropy(
        all_decoder_outputs.transpose(0, 1).contiguous(),
        output_batch.transpose(0, 1).contiguous(),
        output_data_len)

    if l >= 20:
        break

# %%
loss
# Out:
# tensor(10.8263, device='cuda:0', grad_fn=<DivBackward1>)

# %% [markdown]
# Testing without teaching force

# %%
encoder_optimizer = optim.SGD(encoder1.parameters(), lr=0.1)
decoder_optimizer = optim.SGD(decoder1.parameters(), lr=0.1)
criterion = nn.NLLLoss()

for l, (input_var,input_data_len,output_var,output_data_len) in enumerate(train_loader):
    input_batch = input_var.transpose(0,1).to(device)
    output_batch = output_var.transpose(0,1).to(device)
    encoder_outputs, encoder_hidden = encoder1(input_batch, input_data_len, None)
  
    max_target_length = MAX_LENGTH
    # Prepare decoder input and outputs
    decoder_input = Variable(torch.LongTensor([SOS_token] * BATCH_SIZE)).to(device)
    decoder_hidden = encoder_hidden[:decoder1.n_layers] # Use last (forward) hidden state from encoder
    all_decoder_outputs = Variable(torch.zeros(max_target_length, BATCH_SIZE, decoder1.output_size)).to(device)
    loss = 0
  
    # Run through decoder one time step at a time
    for t in range(max_target_length):
        decoder_output, decoder_hidden = decoder1(
        decoder_input, decoder_hidden
    )
        
        topv, topi = decoder_output.topk(1)
        decoder_input = topi.squeeze().detach()  # detach from history as input
        all_decoder_outputs[t] = decoder_output # Store this step's outputs
    
    # Test masked cross entropy loss
    loss = masked_cross_entropy(
        all_decoder_outputs.transpose(0, 1).contiguous(),
        output_batch.transpose(0, 1).contiguous(),
        output_data_len)

    if l >= 1:
        break

# %%
loss
# Out:
# tensor(10.8258, device='cuda:0', grad_fn=<DivBackward1>)

# %%
#the train function is now taking a batch at a time
def train(input_batch, input_lengths, output_batch, output_lengths, encoder, decoder, encoder_optimizer, 
          decoder_optimizer, criterion, max_length=MAX_LENGTH, if_attention = False):
    
    encoder_outputs, encoder_hidden = encoder(input_batch, input_lengths, None)
  

    # Prepare decoder input and outputs
    decoder_input = Variable(torch.LongTensor([SOS_token] * BATCH_SIZE)).to(device)
    decoder_hidden = encoder_hidden[:decoder.n_layers] # Use last (forward) hidden state from encoder
    all_decoder_outputs = Variable(torch.zeros(max_length, BATCH_SIZE, decoder.output_size)).to(device)
    
    # Run through decoder one time step at a time
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False
    
    # Teacher forcing: Feed the target as the next input
    if use_teacher_forcing:
        # Run through decoder one time step at a time
        for di in range(max_length):
            if if_attention == True:
                decoder_output, decoder_hidden, decoder_attn = decoder(
                    decoder_input, decoder_hidden, encoder_outputs)
            else:

                decoder_output, decoder_hidden = decoder(
                    decoder_input, decoder_hidden)
                
            all_decoder_outputs[di] = decoder_output # Store this step's outputs
            decoder_input = output_batch[di] # Next input is current target

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(max_length):
            if if_attention == True:
                decoder_output, decoder_hidden, decoder_attn = decoder(
                  decoder_input, decoder_hidden, encoder_outputs)
            else:

                decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden)
                
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input
            all_decoder_outputs[di] = decoder_output

    
    # Loss calculation and backpropagation
    loss = masked_cross_entropy(
            all_decoder_outputs.transpose(0, 1).contiguous(), # -> batch x seq
            output_batch.transpose(0, 1).contiguous(), # -> batch x seq
            output_lengths)    

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()
      


    return loss.item()

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss()
    iters = 0
    
    while iters <= n_iters:
      
      
      
      for i, (input_var,input_data_len,output_var,output_data_len) in enumerate(train_loader):
        iters += 1
        input_batch = input_var.transpose(0,1).to(device)
        output_batch = output_var.transpose(0,1).to(device)
        
        loss = train(input_batch,input_data_len,output_batch,output_data_len, encoder,
                       decoder, encoder_optimizer, decoder_optimizer, criterion)
       
        
        # Keep track of loss
        print_loss_total += loss
        plot_loss_total += loss


        if iters % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iters / n_iters),
                                           iters, iters / n_iters * 100, print_loss_avg))

        if iters % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# Training model on sample data, without attention mechanism. Using pre-trained word embedding for both languages, and not updating the weights

# %%
# Configure models
hidden_size = 500
layers = 2
teacher_forcing_ratio = 0.5
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iters = 10000

# Initialize models
encoder = EncoderRNN(weights_matrix_zh, train_input_lang.n_words, hidden_size, n_layers = layers).to(device)
decoder = DecoderRNN(weights_matrix_eng, hidden_size, train_output_lang.n_words, n_layers = layers).to(device)

# Initialize optimizers and criterion
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
criterion = nn.CrossEntropyLoss()

# %%
trainIters(encoder, decoder, n_iters, print_every=100, plot_every=100, learning_rate=learning_rate)
# Out:
# 1m 11s (- 117m 56s) (100 1%) 10.8178
# 2m 22s (- 116m 30s) (200 2%) 10.7931
# 3m 33s (- 114m 56s) (300 3%) 10.7411
# 4m 43s (- 113m 27s) (400 4%) 10.6561
# 5m 54s (- 112m 11s) (500 5%) 10.5224
# 7m 4s (- 110m 51s) (600 6%) 10.2594
# 8m 14s (- 109m 32s) (700 7%) 9.5737
# 9m 25s (- 108m 19s) (800 8%) 9.3512
# 10m 35s (- 107m 6s) (900 9%) 9.1628
# 11m 45s (- 105m 48s) (1000 10%) 8.9847
# 12m 54s (- 104m 29s) (1100 11%) 8.6063
# 14m 4s (- 103m 15s) (1200 12%) 8.1901
# 15m 14s (- 102m 1s) (1300 13%) 8.1998
# 16m 25s (- 100m 51s) (1400 14%) 8.0658
# 17m 35s (- 99m 40s) (1500 15%) 8.1448
# 18m 45s (- 98m 30s) (1600 16%) 8.0000
# 19m 55s (- 97m 18s) (1700 17%) 7.7528
# 21m 5s (- 96m 6s) (1800 18%) 7.7712
# 22m 15s (- 94m 54s) (1900 19%) 7.7044
# 23m 25s (- 93m 43s) (2000 20%) 7.5315
# 24m 36s (- 92m 32s) (2100 21%) 7.5286
# 25m 45s (- 91m 21s) (2200 22%) 7.4363
# 26m 56s (- 90m 10s) (2300 23%) 7.3637
# 28m 6s (- 89m 0s) (2400 24%) 7.3265
# 29m 16s (- 87m 49s) (2500 25%) 7.2505
# 30m 26s (- 86m 38s) (2600 26%) 7.1977
# 31m 36s (- 85m 27s) (2700 27%) 7.1186
# 32m 46s (- 84m 15s) (2800 28%) 7.0837
# 33m 56s (- 83m 5s) (2900 28%) 6.9774
# 35m 5s (- 81m 53s) (3000 30%) 6.8977
# 36m 16s (- 80m 43s) (3100 31%) 6.8924
# 37m 26s (- 79m 33s) (3200 32%) 6.8301
# 38m 36s (- 78m 23s) (3300 33%) 6.7288
# 39m 46s (- 77m 12s) (3400 34%) 6.6643
# 40m 56s (- 76m 1s) (3500 35%) 6.6063
# 42m 6s (- 74m 51s) (3600 36%) 6.6339
# 43m 16s (- 73m 41s) (3700 37%) 6.5782
# 44m 27s (- 72m 31s) (3800 38%) 6.5772
# 45m 36s (- 71m 20s) (3900 39%) 6.5051
# 46m 47s (- 70m 10s) (4000 40%) 6.4634
# 47m 57s (- 69m 0s) (4100 41%) 6.4331
# 49m 6s (- 67m 49s) (4200 42%) 6.4026
# 50m 16s (- 66m 39s) (4300 43%) 6.3954
# 51m 26s (- 65m 28s) (4400 44%) 6.3502
# 52m 36s (- 64m 18s) (4500 45%) 6.3462
# 53m 46s (- 63m 8s) (4600 46%) 6.3285
# 54m 56s (- 61m 57s) (4700 47%) 6.2628
# 56m 6s (- 60m 47s) (4800 48%) 6.2683
# 57m 16s (- 59m 36s) (4900 49%) 6.2711
# 58m 26s (- 58m 26s) (5000 50%) 6.2631
# 59m 36s (- 57m 16s) (5100 51%) 6.2900
# 60m 46s (- 56m 5s) (5200 52%) 6.2209
# 61m 55s (- 54m 55s) (5300 53%) 6.2595
# 63m 5s (- 53m 44s) (5400 54%) 6.2546
# 64m 15s (- 52m 34s) (5500 55%) 6.2188
# 65m 25s (- 51m 23s) (5600 56%) 6.2538
# 66m 34s (- 50m 13s) (5700 56%) 6.2175
# 67m 44s (- 49m 3s) (5800 57%) 6.2380
# 68m 54s (- 47m 53s) (5900 59%) 6.2324
# 70m 4s (- 46m 43s) (6000 60%) 6.2450
# 71m 14s (- 45m 33s) (6100 61%) 6.2483
# 72m 25s (- 44m 23s) (6200 62%) 6.1890
# 73m 35s (- 43m 13s) (6300 63%) 6.1894
# 74m 45s (- 42m 3s) (6400 64%) 6.1158
# 75m 55s (- 40m 53s) (6500 65%) 6.1374
# 77m 6s (- 39m 43s) (6600 66%) 6.1498
# 78m 16s (- 38m 33s) (6700 67%) 6.1026
# 79m 25s (- 37m 22s) (6800 68%) 6.0912
# 80m 36s (- 36m 12s) (6900 69%) 6.0974
# 81m 46s (- 35m 2s) (7000 70%) 6.0743
# 82m 56s (- 33m 52s) (7100 71%) 6.0917
# 84m 5s (- 32m 42s) (7200 72%) 6.0600
# 85m 15s (- 31m 32s) (7300 73%) 6.0289
# 86m 25s (- 30m 21s) (7400 74%) 6.1064
# 87m 35s (- 29m 11s) (7500 75%) 6.0489
# 88m 45s (- 28m 1s) (7600 76%) 6.0421
# 89m 55s (- 26m 51s) (7700 77%) 6.0543
# 91m 5s (- 25m 41s) (7800 78%) 6.0191
# 92m 15s (- 24m 31s) (7900 79%) 6.0426
# 93m 25s (- 23m 21s) (8000 80%) 6.0328
# 94m 35s (- 22m 11s) (8100 81%) 5.9869
# 95m 45s (- 21m 1s) (8200 82%) 6.0368
# 96m 55s (- 19m 51s) (8300 83%) 6.1112
# 98m 5s (- 18m 40s) (8400 84%) 6.0580
# 99m 15s (- 17m 30s) (8500 85%) 6.0423
# 100m 25s (- 16m 20s) (8600 86%) 5.9553
# 101m 34s (- 15m 10s) (8700 87%) 5.9491
# 102m 44s (- 14m 0s) (8800 88%) 5.9738
# 103m 54s (- 12m 50s) (8900 89%) 5.9943
# 105m 4s (- 11m 40s) (9000 90%) 5.9746
# 106m 14s (- 10m 30s) (9100 91%) 5.9442
# 107m 23s (- 9m 20s) (9200 92%) 5.9390
# 108m 33s (- 8m 10s) (9300 93%) 5.9877
# 109m 43s (- 7m 0s) (9400 94%) 5.8900
# 110m 53s (- 5m 50s) (9500 95%) 5.9604
# 112m 3s (- 4m 40s) (9600 96%) 5.9519
# 113m 12s (- 3m 30s) (9700 97%) 5.9573
# 114m 22s (- 2m 20s) (9800 98%) 5.8912
# 115m 32s (- 1m 10s) (9900 99%) 5.9181
# 116m 42s (- 0m 0s) (10000 100%) 5.9118
# 117m 52s (- -2m 49s) (10100 101%) 5.9077
# 119m 2s (- -3m 39s) (10200 102%) 5.9103
# 120m 12s (- -4m 29s) (10300 103%) 5.8501
# 121m 22s (- -5m 19s) (10400 104%) 5.8110
# 122m 32s (- -6m 9s) (10500 105%) 5.8773
# 123m 42s (- -8m 59s) (10600 106%) 5.8792
# 124m 52s (- -9m 49s) (10700 107%) 5.8437
# 126m 2s (- -10m 39s) (10800 108%) 5.7995
# 127m 12s (- -11m 29s) (10900 109%) 5.7884
# 128m 22s (- -12m 19s) (11000 110%) 5.7948
# 129m 32s (- -13m 9s) (11100 111%) 5.7684
# 130m 43s (- -15m 59s) (11200 112%) 5.7963
# 131m 53s (- -16m 49s) (11300 112%) 5.7918
# 133m 3s (- -17m 39s) (11400 113%) 5.8104
# 134m 13s (- -18m 29s) (11500 114%) 5.7741
# 135m 24s (- -19m 19s) (11600 115%) 5.7854
# 136m 34s (- -20m 9s) (11700 117%) 5.7835
# 137m 44s (- -22m 59s) (11800 118%) 5.7497
# 138m 54s (- -23m 49s) (11900 119%) 5.7286
# 140m 5s (- -24m 39s) (12000 120%) 5.7333
# 141m 15s (- -25m 29s) (12100 121%) 5.7124
# 142m 25s (- -26m 19s) (12200 122%) 5.7476
# 143m 35s (- -27m 8s) (12300 123%) 5.7207
# 144m 45s (- -29m 58s) (12400 124%) 5.7152
# 145m 55s (- -30m 48s) (12500 125%) 5.6836
# 147m 5s (- -31m 38s) (12600 126%) 5.6900
# 148m 15s (- -32m 28s) (12700 127%) 5.7776
# 149m 25s (- -33m 18s) (12800 128%) 5.7167
# 150m 35s (- -34m 8s) (12900 129%) 5.7251
# 151m 45s (- -36m 58s) (13000 130%) 5.7240
# 152m 55s (- -37m 48s) (13100 131%) 5.7260
# 154m 5s (- -38m 38s) (13200 132%) 5.7315
# 155m 15s (- -39m 28s) (13300 133%) 5.6795
# 156m 25s (- -40m 18s) (13400 134%) 5.6951
# 157m 34s (- -41m 8s) (13500 135%) 5.6449
# 158m 44s (- -43m 58s) (13600 136%) 5.7107
# 159m 54s (- -44m 48s) (13700 137%) 5.6710
# 161m 4s (- -45m 38s) (13800 138%) 5.6954
# 162m 14s (- -46m 28s) (13900 139%) 5.6618
# 163m 24s (- -47m 18s) (14000 140%) 5.6472
# 164m 34s (- -48m 8s) (14100 141%) 5.6468
# 165m 44s (- -50m 58s) (14200 142%) 5.5968
# 166m 54s (- -51m 48s) (14300 143%) 5.6225
# 168m 4s (- -52m 38s) (14400 144%) 5.6435
# 169m 14s (- -53m 28s) (14500 145%) 5.6440
# 170m 24s (- -54m 18s) (14600 146%) 5.6407

# %%
torch.save(encoder.state_dict(), folder_path + 'encoder2.pt')
torch.save(decoder.state_dict(), folder_path + 'decoder2.pt')

# %% [markdown]
# Training Model: Nov. 28th

# %%
# Configure models
hidden_size = 500
layers = 2
teacher_forcing_ratio = 0.5
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iters = 10000

encoder2 = EncoderRNN(weights_matrix_zh, train_input_lang.n_words, hidden_size, n_layers = layers).to(device)
decoder2 = DecoderRNN(weights_matrix_eng, hidden_size, train_output_lang.n_words, n_layers = layers).to(device)
encoder2.load_state_dict(torch.load(folder_path + "encoder2.pt"))
decoder2.load_state_dict(torch.load(folder_path +"decoder2.pt"))

# %%
trainIters(encoder2, decoder2, n_iters, print_every=100, plot_every=100, learning_rate=learning_rate)
# Out:
# 1m 10s (- 115m 59s) (100 1%) 5.5975
# 2m 20s (- 114m 32s) (200 2%) 5.5513
# 3m 30s (- 113m 15s) (300 3%) 5.5141
# 4m 39s (- 111m 56s) (400 4%) 5.5060
# 5m 49s (- 110m 49s) (500 5%) 5.5657
# 7m 0s (- 109m 42s) (600 6%) 5.5435
# 8m 10s (- 108m 35s) (700 7%) 5.5424
# 9m 20s (- 107m 23s) (800 8%) 5.4890
# 10m 30s (- 106m 17s) (900 9%) 5.5470
# 11m 41s (- 105m 11s) (1000 10%) 5.5296
# 12m 51s (- 104m 5s) (1100 11%) 5.5616
# 14m 2s (- 102m 57s) (1200 12%) 5.5474
# 15m 12s (- 101m 48s) (1300 13%) 5.5131
# 16m 23s (- 100m 39s) (1400 14%) 5.5158
# 17m 33s (- 99m 29s) (1500 15%) 5.4853
# 18m 43s (- 98m 20s) (1600 16%) 5.6163
# 19m 54s (- 97m 9s) (1700 17%) 5.5137
# 21m 4s (- 96m 1s) (1800 18%) 5.5727
# 22m 15s (- 94m 51s) (1900 19%) 5.5330
# 23m 25s (- 93m 41s) (2000 20%) 5.5151
# 24m 35s (- 92m 32s) (2100 21%) 5.6084
# 25m 46s (- 91m 22s) (2200 22%) 5.5317
# 26m 56s (- 90m 12s) (2300 23%) 5.5578
# 28m 6s (- 89m 1s) (2400 24%) 5.5048
# 29m 17s (- 87m 52s) (2500 25%) 5.5931
# 30m 27s (- 86m 41s) (2600 26%) 5.5273
# 31m 38s (- 85m 32s) (2700 27%) 5.5987
# 32m 48s (- 84m 22s) (2800 28%) 5.5515
# 33m 58s (- 83m 11s) (2900 28%) 5.5297
# 35m 9s (- 82m 1s) (3000 30%) 5.5470
# 36m 19s (- 80m 51s) (3100 31%) 5.5311
# 37m 29s (- 79m 41s) (3200 32%) 5.5672
# 38m 40s (- 78m 30s) (3300 33%) 5.5535
# 39m 50s (- 77m 20s) (3400 34%) 5.5860
# 41m 0s (- 76m 10s) (3500 35%) 5.5703
# 42m 10s (- 74m 59s) (3600 36%) 5.5562
# 43m 21s (- 73m 49s) (3700 37%) 5.5929
# 44m 31s (- 72m 39s) (3800 38%) 5.5850
# 45m 42s (- 71m 29s) (3900 39%) 5.6201
# 46m 52s (- 70m 19s) (4000 40%) 5.5942
# 48m 3s (- 69m 9s) (4100 41%) 5.5927
# 49m 13s (- 67m 59s) (4200 42%) 5.6005
# 50m 24s (- 66m 49s) (4300 43%) 5.6756
# 51m 34s (- 65m 38s) (4400 44%) 5.5917
# 52m 45s (- 64m 28s) (4500 45%) 5.6110
# 53m 56s (- 63m 18s) (4600 46%) 5.6571
# 55m 6s (- 62m 8s) (4700 47%) 5.5935
# 56m 17s (- 60m 58s) (4800 48%) 5.6083
# 57m 27s (- 59m 48s) (4900 49%) 5.5933
# 58m 38s (- 58m 38s) (5000 50%) 5.5491
# 59m 48s (- 57m 28s) (5100 51%) 5.5587
# 60m 59s (- 56m 17s) (5200 52%) 5.5977
# 62m 9s (- 55m 7s) (5300 53%) 5.5099
# 63m 20s (- 53m 57s) (5400 54%) 5.5352
# 64m 30s (- 52m 46s) (5500 55%) 5.5885
# 65m 41s (- 51m 36s) (5600 56%) 5.5571
# 66m 51s (- 50m 26s) (5700 56%) 5.4844
# 68m 1s (- 49m 15s) (5800 57%) 5.4829
# 69m 12s (- 48m 5s) (5900 59%) 5.5880
# 70m 22s (- 46m 55s) (6000 60%) 5.5487
# 71m 33s (- 45m 44s) (6100 61%) 5.5657
# 72m 43s (- 44m 34s) (6200 62%) 5.5248
# 73m 53s (- 43m 23s) (6300 63%) 5.4579
# 75m 3s (- 42m 13s) (6400 64%) 5.5005
# 76m 13s (- 41m 2s) (6500 65%) 5.5282
# 77m 24s (- 39m 52s) (6600 66%) 5.5039
# 78m 34s (- 38m 41s) (6700 67%) 5.4580
# 79m 44s (- 37m 31s) (6800 68%) 5.5597
# 80m 55s (- 36m 21s) (6900 69%) 5.4911
# 82m 5s (- 35m 10s) (7000 70%) 5.5387
# 83m 16s (- 34m 0s) (7100 71%) 5.5802
# 84m 26s (- 32m 50s) (7200 72%) 5.5381
# 85m 36s (- 31m 39s) (7300 73%) 5.4990
# 86m 47s (- 30m 29s) (7400 74%) 5.4842
# 87m 57s (- 29m 19s) (7500 75%) 5.4917
# 89m 8s (- 28m 9s) (7600 76%) 5.5082
# 90m 19s (- 26m 58s) (7700 77%) 5.5390
# 91m 30s (- 25m 48s) (7800 78%) 5.4857
# 92m 40s (- 24m 38s) (7900 79%) 5.4736
# 93m 51s (- 23m 27s) (8000 80%) 5.4803
# 95m 2s (- 22m 17s) (8100 81%) 5.4978
# 96m 12s (- 21m 7s) (8200 82%) 5.4762
# 97m 22s (- 19m 56s) (8300 83%) 5.4804
# 98m 32s (- 18m 46s) (8400 84%) 5.3617
# 99m 43s (- 17m 35s) (8500 85%) 5.4831
# 100m 54s (- 16m 25s) (8600 86%) 5.4502
# 102m 4s (- 15m 15s) (8700 87%) 5.4359
# 103m 15s (- 14m 4s) (8800 88%) 5.4545
# 104m 26s (- 12m 54s) (8900 89%) 5.4999
# 105m 36s (- 11m 44s) (9000 90%) 5.4546
# 106m 47s (- 10m 33s) (9100 91%) 5.4264
# 107m 57s (- 9m 23s) (9200 92%) 5.3808
# 109m 8s (- 8m 12s) (9300 93%) 5.4473
# 110m 18s (- 7m 2s) (9400 94%) 5.4301
# 111m 28s (- 5m 52s) (9500 95%) 5.4514
# 112m 38s (- 4m 41s) (9600 96%) 5.4600
# 113m 48s (- 3m 31s) (9700 97%) 5.4782
# 114m 58s (- 2m 20s) (9800 98%) 5.4183
# 116m 8s (- 1m 10s) (9900 99%) 5.4131
# 117m 19s (- 0m 0s) (10000 100%) 5.4308
# 118m 29s (- -2m 49s) (10100 101%) 5.5033
# 119m 39s (- -3m 39s) (10200 102%) 5.4046
# 120m 49s (- -4m 28s) (10300 103%) 5.3614
# 121m 59s (- -5m 18s) (10400 104%) 5.3880
# 123m 9s (- -6m 8s) (10500 105%) 5.3538
# 124m 19s (- -8m 57s) (10600 106%) 5.3214
# 125m 29s (- -9m 47s) (10700 107%) 5.3621
# 126m 39s (- -10m 37s) (10800 108%) 5.3050
# 127m 49s (- -11m 26s) (10900 109%) 5.4171
# 128m 59s (- -12m 16s) (11000 110%) 5.3334
# 130m 9s (- -13m 6s) (11100 111%) 5.3350
# 131m 19s (- -15m 55s) (11200 112%) 5.3670
# 132m 30s (- -16m 45s) (11300 112%) 5.4433
# 133m 40s (- -17m 35s) (11400 113%) 5.3557
# 134m 50s (- -18m 24s) (11500 114%) 5.3205
# 136m 0s (- -19m 14s) (11600 115%) 5.3566
# 137m 11s (- -20m 4s) (11700 117%) 5.3954
# 138m 21s (- -22m 53s) (11800 118%) 5.3251
# 139m 31s (- -23m 43s) (11900 119%) 5.3822
# 140m 41s (- -24m 33s) (12000 120%) 5.2606
# 141m 51s (- -25m 22s) (12100 121%) 5.3156
# 143m 1s (- -26m 12s) (12200 122%) 5.3389
# 144m 11s (- -27m 2s) (12300 123%) 5.3235
# 145m 22s (- -29m 51s) (12400 124%) 5.3787
# 146m 32s (- -30m 41s) (12500 125%) 5.3913
# 147m 42s (- -31m 31s) (12600 126%) 5.2604
# 148m 52s (- -32m 20s) (12700 127%) 5.3053
# 150m 2s (- -33m 10s) (12800 128%) 5.3205
# 151m 13s (- -34m 0s) (12900 129%) 5.3224
# 152m 23s (- -36m 50s) (13000 130%) 5.2840
# 153m 33s (- -37m 39s) (13100 131%) 5.2865
# 154m 43s (- -38m 29s) (13200 132%) 5.3624
# 155m 54s (- -39m 19s) (13300 133%) 5.2847
# 157m 4s (- -40m 8s) (13400 134%) 5.3359
# 158m 14s (- -42m 58s) (13500 135%) 5.3747
# 159m 25s (- -43m 48s) (13600 136%) 5.3332
# 160m 35s (- -44m 37s) (13700 137%) 5.2636
# 161m 45s (- -45m 27s) (13800 138%) 5.3005
# 162m 54s (- -46m 17s) (13900 139%) 5.2566
# 164m 4s (- -47m 7s) (14000 140%) 5.2883
# 165m 15s (- -49m 56s) (14100 141%) 5.3279
# 166m 25s (- -50m 46s) (14200 142%) 5.2277
# 167m 35s (- -51m 36s) (14300 143%) 5.3297
# 168m 45s (- -52m 26s) (14400 144%) 5.2274
# 169m 55s (- -53m 15s) (14500 145%) 5.3178
# 171m 5s (- -54m 5s) (14600 146%) 5.2874

# %%
torch.save(encoder2.state_dict(), folder_path + 'encoder3.pt')
torch.save(decoder2.state_dict(), folder_path + 'decoder3.pt')

# %% [markdown]
# Training Model: Nov 30th

# %%
# Configure models
hidden_size = 500
layers = 2
teacher_forcing_ratio = 0.5
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iters = 10000

encoder3 = EncoderRNN(weights_matrix_zh, train_input_lang.n_words, hidden_size, n_layers = layers).to(device)
decoder3 = DecoderRNN(weights_matrix_eng, hidden_size, train_output_lang.n_words, n_layers = layers).to(device)
encoder3.load_state_dict(torch.load(folder_path + "encoder3.pt"))
decoder3.load_state_dict(torch.load(folder_path +"decoder3.pt"))

# %%
trainIters(encoder3, decoder3, n_iters, print_every=100, plot_every=100, learning_rate=learning_rate)
# Out:
# 1m 12s (- 119m 54s) (100 1%) 5.3020
# 2m 25s (- 118m 30s) (200 2%) 5.2259
# 3m 37s (- 117m 12s) (300 3%) 5.2173
# 4m 49s (- 115m 54s) (400 4%) 5.1294
# 6m 2s (- 114m 41s) (500 5%) 5.1952
# 7m 14s (- 113m 29s) (600 6%) 5.2293
# 8m 27s (- 112m 19s) (700 7%) 5.2073
# 9m 40s (- 111m 10s) (800 8%) 5.2156
# 10m 52s (- 109m 58s) (900 9%) 5.2079
# 12m 5s (- 108m 47s) (1000 10%) 5.1818
# 13m 17s (- 107m 34s) (1100 11%) 5.1819
# 14m 30s (- 106m 21s) (1200 12%) 5.1847
# 15m 42s (- 105m 9s) (1300 13%) 5.1598
# 16m 55s (- 103m 58s) (1400 14%) 5.2264
# 18m 8s (- 102m 47s) (1500 15%) 5.1932
# 19m 20s (- 101m 33s) (1600 16%) 5.0898
# 20m 33s (- 100m 21s) (1700 17%) 5.1719
# 21m 45s (- 99m 8s) (1800 18%) 5.1086
# 22m 58s (- 97m 56s) (1900 19%) 5.1683
# 24m 11s (- 96m 44s) (2000 20%) 5.2070
# 25m 23s (- 95m 30s) (2100 21%) 5.1358
# 26m 35s (- 94m 17s) (2200 22%) 5.1514
# 27m 47s (- 93m 4s) (2300 23%) 5.0986
# 29m 0s (- 91m 51s) (2400 24%) 5.1812
# 30m 13s (- 90m 39s) (2500 25%) 5.1921
# 31m 25s (- 89m 26s) (2600 26%) 5.1287
# 32m 38s (- 88m 14s) (2700 27%) 5.1470
# 33m 50s (- 87m 1s) (2800 28%) 5.1904
# 35m 2s (- 85m 48s) (2900 28%) 5.0915
# 36m 15s (- 84m 35s) (3000 30%) 5.1888
# 37m 27s (- 83m 23s) (3100 31%) 5.1739
# 38m 40s (- 82m 11s) (3200 32%) 5.1746
# 39m 52s (- 80m 58s) (3300 33%) 5.1258
# 41m 5s (- 79m 45s) (3400 34%) 5.1806
# 42m 17s (- 78m 32s) (3500 35%) 5.1005
# 43m 30s (- 77m 20s) (3600 36%) 5.1478
# 44m 42s (- 76m 7s) (3700 37%) 5.1446
# 45m 54s (- 74m 54s) (3800 38%) 5.1185
# 47m 6s (- 73m 41s) (3900 39%) 5.1899
# 48m 18s (- 72m 28s) (4000 40%) 5.1016
# 49m 31s (- 71m 16s) (4100 41%) 5.1385
# 50m 44s (- 70m 3s) (4200 42%) 5.1673
# 51m 56s (- 68m 51s) (4300 43%) 5.0598
# 53m 8s (- 67m 38s) (4400 44%) 5.2153
# 54m 21s (- 66m 26s) (4500 45%) 5.1658
# 55m 33s (- 65m 13s) (4600 46%) 5.1180
# 56m 46s (- 64m 1s) (4700 47%) 5.1081
# 57m 58s (- 62m 48s) (4800 48%) 5.0810
# 59m 11s (- 61m 36s) (4900 49%) 5.1514
# 60m 23s (- 60m 23s) (5000 50%) 5.0643
# 61m 35s (- 59m 10s) (5100 51%) 5.0889
# 62m 47s (- 57m 58s) (5200 52%) 5.0937
# 64m 0s (- 56m 45s) (5300 53%) 5.0548
# 65m 13s (- 55m 33s) (5400 54%) 5.1567
# 66m 25s (- 54m 21s) (5500 55%) 5.1885
# 67m 38s (- 53m 8s) (5600 56%) 5.0830
# 68m 50s (- 51m 56s) (5700 56%) 5.0896
# 70m 3s (- 50m 43s) (5800 57%) 5.0556
# 71m 15s (- 49m 31s) (5900 59%) 5.1514
# 72m 28s (- 48m 18s) (6000 60%) 5.1045
# 73m 40s (- 47m 6s) (6100 61%) 5.1294
# 74m 53s (- 45m 54s) (6200 62%) 5.1289
# 76m 5s (- 44m 41s) (6300 63%) 5.0946
# 77m 17s (- 43m 28s) (6400 64%) 5.0512
# 78m 29s (- 42m 16s) (6500 65%) 5.0384
# 79m 42s (- 41m 3s) (6600 66%) 5.0985
# 80m 54s (- 39m 51s) (6700 67%) 5.0891
# 82m 7s (- 38m 38s) (6800 68%) 5.0873
# 83m 19s (- 37m 26s) (6900 69%) 5.0906
# 84m 32s (- 36m 14s) (7000 70%) 5.1190
# 85m 45s (- 35m 1s) (7100 71%) 5.0395
# 86m 57s (- 33m 49s) (7200 72%) 5.0873
# 88m 10s (- 32m 36s) (7300 73%) 5.0563
# 89m 22s (- 31m 24s) (7400 74%) 5.0200
# 90m 35s (- 30m 11s) (7500 75%) 5.0246
# 91m 47s (- 28m 59s) (7600 76%) 5.1106
# 93m 0s (- 27m 46s) (7700 77%) 5.0521
# 94m 13s (- 26m 34s) (7800 78%) 5.0892
# 95m 25s (- 25m 21s) (7900 79%) 4.9900
# 96m 37s (- 24m 9s) (8000 80%) 5.0401
# 97m 50s (- 22m 56s) (8100 81%) 5.1057
# 99m 2s (- 21m 44s) (8200 82%) 5.0906
# 100m 15s (- 20m 32s) (8300 83%) 5.0974
# 101m 27s (- 19m 19s) (8400 84%) 5.0473
# 102m 40s (- 18m 7s) (8500 85%) 5.0826
# 103m 52s (- 16m 54s) (8600 86%) 5.0382
# 105m 5s (- 15m 42s) (8700 87%) 5.1125
# 106m 18s (- 14m 29s) (8800 88%) 5.1290
# 107m 30s (- 13m 17s) (8900 89%) 5.0524
# 108m 43s (- 12m 4s) (9000 90%) 5.1138
# 109m 55s (- 10m 52s) (9100 91%) 5.0041
# 111m 7s (- 9m 39s) (9200 92%) 4.9743
# 112m 20s (- 8m 27s) (9300 93%) 5.1645
# 113m 33s (- 7m 14s) (9400 94%) 5.1393
# 114m 45s (- 6m 2s) (9500 95%) 4.9971
# 115m 57s (- 4m 49s) (9600 96%) 5.0189
# 117m 10s (- 3m 37s) (9700 97%) 5.1379
# 118m 22s (- 2m 24s) (9800 98%) 5.0552
# 119m 35s (- 1m 12s) (9900 99%) 5.0272
# 120m 47s (- 0m 0s) (10000 100%) 5.0539
# 122m 0s (- -2m 47s) (10100 101%) 5.0384
# 123m 12s (- -3m 35s) (10200 102%) 5.0844
# 124m 25s (- -4m 22s) (10300 103%) 5.0268
# 125m 38s (- -5m 10s) (10400 104%) 5.0629
# 126m 50s (- -7m 57s) (10500 105%) 5.0149
# 128m 2s (- -8m 45s) (10600 106%) 4.9908
# 129m 14s (- -9m 32s) (10700 107%) 5.0457
# 130m 26s (- -10m 20s) (10800 108%) 5.0889
# 131m 38s (- -11m 7s) (10900 109%) 5.0782
# 132m 50s (- -13m 55s) (11000 110%) 5.0173
# 134m 1s (- -14m 43s) (11100 111%) 5.0768
# 135m 13s (- -15m 30s) (11200 112%) 5.0025
# 136m 24s (- -16m 18s) (11300 112%) 4.9994
# 137m 36s (- -17m 6s) (11400 113%) 5.0823
# 138m 48s (- -19m 53s) (11500 114%) 5.0952
# 139m 59s (- -20m 41s) (11600 115%) 4.9901
# 141m 11s (- -21m 29s) (11700 117%) 4.9836
# 142m 22s (- -22m 16s) (11800 118%) 4.9546
# 143m 35s (- -23m 4s) (11900 119%) 5.0655
# 144m 47s (- -25m 52s) (12000 120%) 5.0414
# 146m 0s (- -26m 39s) (12100 121%) 5.0699
# 147m 12s (- -27m 27s) (12200 122%) 4.9805
# 148m 24s (- -28m 14s) (12300 123%) 5.0207
# 149m 37s (- -29m 2s) (12400 124%) 4.9673
# 150m 49s (- -31m 50s) (12500 125%) 5.0471
# 152m 2s (- -32m 37s) (12600 126%) 4.9769
# 153m 14s (- -33m 25s) (12700 127%) 5.0217
# 154m 27s (- -34m 12s) (12800 128%) 5.0045
# 155m 39s (- -35m 0s) (12900 129%) 4.9541
# 156m 52s (- -37m 47s) (13000 130%) 5.0081
# 158m 5s (- -38m 35s) (13100 131%) 5.0008
# 159m 17s (- -39m 22s) (13200 132%) 5.0482
# 160m 30s (- -40m 10s) (13300 133%) 5.0032
# 161m 42s (- -42m 58s) (13400 134%) 5.0178
# 162m 55s (- -43m 45s) (13500 135%) 5.0047
# 164m 7s (- -44m 33s) (13600 136%) 4.8891
# 165m 19s (- -45m 20s) (13700 137%) 4.9007
# 166m 32s (- -46m 8s) (13800 138%) 5.0478
# 167m 45s (- -48m 55s) (13900 139%) 4.9904
# 168m 57s (- -49m 43s) (14000 140%) 4.9598
# 170m 10s (- -50m 31s) (14100 141%) 4.9964
# 171m 22s (- -51m 18s) (14200 142%) 5.0068
# 172m 35s (- -52m 6s) (14300 143%) 4.9478
# 173m 47s (- -54m 53s) (14400 144%) 4.9646
# 175m 0s (- -55m 41s) (14500 145%) 4.9275
# 176m 13s (- -56m 28s) (14600 146%) 5.0265

# %%
torch.save(encoder3.state_dict(), folder_path + 'encoder3.pt')
torch.save(decoder3.state_dict(), folder_path + 'decoder3.pt')

# %%
trainIters(encoder3, decoder3, n_iters, print_every=100, plot_every=100, learning_rate=learning_rate)
# Out:
# 1m 13s (- 120m 44s) (100 1%) 4.9841
# 2m 26s (- 119m 21s) (200 2%) 4.9753
# 3m 39s (- 118m 3s) (300 3%) 4.9653
# 4m 51s (- 116m 41s) (400 4%) 4.9541
# 6m 4s (- 115m 29s) (500 5%) 4.9803
# 7m 17s (- 114m 15s) (600 6%) 4.9509
# 8m 30s (- 112m 59s) (700 7%) 4.9517
# 9m 42s (- 111m 42s) (800 8%) 4.9471
# 10m 55s (- 110m 29s) (900 9%) 5.0089
# 12m 8s (- 109m 13s) (1000 10%) 4.9203
# 13m 20s (- 107m 59s) (1100 11%) 4.9020
# 14m 32s (- 106m 41s) (1200 12%) 4.9097
# 15m 44s (- 105m 22s) (1300 13%) 4.9214
# 16m 56s (- 104m 3s) (1400 14%) 4.9448
# 18m 8s (- 102m 47s) (1500 15%) 4.9365
# 19m 20s (- 101m 33s) (1600 16%) 4.9928
# 20m 32s (- 100m 19s) (1700 17%) 4.9277
# 21m 45s (- 99m 5s) (1800 18%) 4.8891
# 22m 56s (- 97m 49s) (1900 19%) 4.9300
# 24m 8s (- 96m 35s) (2000 20%) 4.8954
# 25m 20s (- 95m 20s) (2100 21%) 4.8914
# 26m 32s (- 94m 6s) (2200 22%) 4.9192
# 27m 44s (- 92m 52s) (2300 23%) 4.9777
# 28m 56s (- 91m 39s) (2400 24%) 5.0269
# 30m 8s (- 90m 26s) (2500 25%) 4.9145
# 31m 20s (- 89m 13s) (2600 26%) 4.9308
# 32m 33s (- 88m 0s) (2700 27%) 4.9122
# 33m 44s (- 86m 46s) (2800 28%) 4.8625
# 34m 56s (- 85m 33s) (2900 28%) 5.0040
# 36m 8s (- 84m 20s) (3000 30%) 4.9795
# 37m 20s (- 83m 7s) (3100 31%) 4.9379
# 38m 32s (- 81m 54s) (3200 32%) 4.9218
# 39m 44s (- 80m 41s) (3300 33%) 4.9499
# 40m 56s (- 79m 28s) (3400 34%) 4.9375
# 42m 8s (- 78m 16s) (3500 35%) 4.9241
# 43m 20s (- 77m 3s) (3600 36%) 4.9347
# 44m 32s (- 75m 51s) (3700 37%) 4.8759
# 45m 44s (- 74m 38s) (3800 38%) 4.9219
# 46m 56s (- 73m 25s) (3900 39%) 4.8777
# 48m 8s (- 72m 13s) (4000 40%) 4.8673
# 49m 20s (- 71m 0s) (4100 41%) 4.8698
# 50m 32s (- 69m 48s) (4200 42%) 4.9067
# 51m 44s (- 68m 35s) (4300 43%) 4.9104
# 52m 56s (- 67m 23s) (4400 44%) 4.8767
# 54m 8s (- 66m 10s) (4500 45%) 4.8491
# 55m 20s (- 64m 58s) (4600 46%) 4.8878
# 56m 33s (- 63m 46s) (4700 47%) 4.9104
# 57m 45s (- 62m 34s) (4800 48%) 4.9423
# 58m 57s (- 61m 22s) (4900 49%) 4.9094
# 60m 9s (- 60m 9s) (5000 50%) 4.8854
# 61m 21s (- 58m 57s) (5100 51%) 4.9583
# 62m 33s (- 57m 45s) (5200 52%) 4.8707
# 63m 45s (- 56m 32s) (5300 53%) 4.8540
# 64m 57s (- 55m 20s) (5400 54%) 4.8534
# 66m 9s (- 54m 8s) (5500 55%) 4.9213
# 67m 21s (- 52m 55s) (5600 56%) 4.9141
# 68m 33s (- 51m 43s) (5700 56%) 4.8488
# 69m 45s (- 50m 31s) (5800 57%) 4.9351
# 70m 57s (- 49m 18s) (5900 59%) 4.8799
# 72m 9s (- 48m 6s) (6000 60%) 4.9282
# 73m 21s (- 46m 54s) (6100 61%) 4.8243
# 74m 33s (- 45m 41s) (6200 62%) 4.7962
# 75m 44s (- 44m 29s) (6300 63%) 4.8520
# 76m 56s (- 43m 16s) (6400 64%) 4.7785
# 78m 7s (- 42m 4s) (6500 65%) 4.7896
# 79m 19s (- 40m 52s) (6600 66%) 4.9450
# 80m 31s (- 39m 39s) (6700 67%) 4.7917
# 81m 42s (- 38m 27s) (6800 68%) 4.8864
# 82m 54s (- 37m 14s) (6900 69%) 4.8266
# 84m 6s (- 36m 2s) (7000 70%) 4.9355
# 85m 17s (- 34m 50s) (7100 71%) 4.8857
# 86m 29s (- 33m 38s) (7200 72%) 4.8775
# 87m 41s (- 32m 25s) (7300 73%) 4.8857
# 88m 52s (- 31m 13s) (7400 74%) 4.8219
# 90m 4s (- 30m 1s) (7500 75%) 4.9321
# 91m 15s (- 28m 49s) (7600 76%) 4.8450
# 92m 27s (- 27m 36s) (7700 77%) 4.8542
# 93m 38s (- 26m 24s) (7800 78%) 4.8495
# 94m 50s (- 25m 12s) (7900 79%) 4.8711
# 96m 1s (- 24m 0s) (8000 80%) 4.8526
# 97m 12s (- 22m 48s) (8100 81%) 4.8466
# 98m 23s (- 21m 35s) (8200 82%) 4.7578
# 99m 35s (- 20m 23s) (8300 83%) 4.9243
# 100m 46s (- 19m 11s) (8400 84%) 4.7694
# 101m 57s (- 17m 59s) (8500 85%) 4.8821
# 103m 8s (- 16m 47s) (8600 86%) 4.8232
# 104m 19s (- 15m 35s) (8700 87%) 4.7206
# 105m 31s (- 14m 23s) (8800 88%) 4.8258
# 106m 42s (- 13m 11s) (8900 89%) 4.8466
# 107m 53s (- 11m 59s) (9000 90%) 4.8976
# 109m 5s (- 10m 47s) (9100 91%) 4.8038
# 110m 16s (- 9m 35s) (9200 92%) 4.8180
# 111m 27s (- 8m 23s) (9300 93%) 4.8521
# 112m 38s (- 7m 11s) (9400 94%) 4.7588
# 113m 49s (- 5m 59s) (9500 95%) 4.9346
# 115m 0s (- 4m 47s) (9600 96%) 4.8576
# 116m 12s (- 3m 35s) (9700 97%) 4.8874
# 117m 23s (- 2m 23s) (9800 98%) 4.8128
# 118m 34s (- 1m 11s) (9900 99%) 4.8153
# 119m 45s (- 0m 0s) (10000 100%) 4.8284
# 120m 56s (- -2m 48s) (10100 101%) 4.7923
# 122m 6s (- -3m 36s) (10200 102%) 4.6611
# 123m 17s (- -4m 24s) (10300 103%) 4.7203
# 124m 28s (- -5m 12s) (10400 104%) 4.8816
# 125m 39s (- -6m 0s) (10500 105%) 4.7860
# 126m 50s (- -8m 49s) (10600 106%) 4.8112
# 128m 1s (- -9m 37s) (10700 107%) 4.7541
# 129m 12s (- -10m 25s) (10800 108%) 4.7557
# 130m 23s (- -11m 14s) (10900 109%) 4.8246
# 131m 34s (- -12m 2s) (11000 110%) 4.8098
# 132m 45s (- -14m 50s) (11100 111%) 4.8161
# 133m 55s (- -15m 39s) (11200 112%) 4.7604
# 135m 6s (- -16m 27s) (11300 112%) 4.7291
# 136m 18s (- -17m 15s) (11400 113%) 4.8735
# 137m 28s (- -18m 4s) (11500 114%) 4.7692
# 138m 39s (- -20m 52s) (11600 115%) 4.8013
# 139m 50s (- -21m 40s) (11700 117%) 4.7478
# 141m 1s (- -22m 29s) (11800 118%) 4.8055
# 142m 13s (- -23m 17s) (11900 119%) 4.8254
# 143m 24s (- -24m 5s) (12000 120%) 4.8156
# 144m 35s (- -26m 54s) (12100 121%) 4.7463
# 145m 45s (- -27m 42s) (12200 122%) 4.7016
# 146m 57s (- -28m 31s) (12300 123%) 4.8376
# 148m 8s (- -29m 19s) (12400 124%) 4.7761
# 149m 19s (- -30m 8s) (12500 125%) 4.8146
# 150m 30s (- -32m 56s) (12600 126%) 4.7985
# 151m 41s (- -33m 45s) (12700 127%) 4.7801
# 152m 52s (- -34m 33s) (12800 128%) 4.7375
# 154m 3s (- -35m 22s) (12900 129%) 4.7861
# 155m 14s (- -36m 10s) (13000 130%) 4.7818
# 156m 25s (- -38m 59s) (13100 131%) 4.7055
# 157m 36s (- -39m 47s) (13200 132%) 4.8336
# 158m 47s (- -40m 35s) (13300 133%) 4.8513
# 159m 58s (- -41m 24s) (13400 134%) 4.7296
# 161m 9s (- -42m 13s) (13500 135%) 4.7809
# 162m 20s (- -43m 1s) (13600 136%) 4.8021
# 163m 32s (- -45m 50s) (13700 137%) 4.8363
# 164m 43s (- -46m 38s) (13800 138%) 4.8437
# 165m 54s (- -47m 27s) (13900 139%) 4.6931
# 167m 4s (- -48m 15s) (14000 140%) 4.6912
# 168m 15s (- -49m 4s) (14100 141%) 4.7314
# 169m 26s (- -51m 52s) (14200 142%) 4.7625
# 170m 37s (- -52m 41s) (14300 143%) 4.8856
# 171m 49s (- -53m 30s) (14400 144%) 4.8677
# 173m 0s (- -54m 18s) (14500 145%) 4.7431
# 174m 11s (- -55m 7s) (14600 146%) 4.7346

# %% [markdown]
# Testing model on validation dataset. Dec 1st

# %%
# Configure models
hidden_size = 500
layers = 2
teacher_forcing_ratio = 0.5
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iters = 10000

encoder3 = EncoderRNN(weights_matrix_zh, train_input_lang.n_words, hidden_size, n_layers = layers).to(device)
decoder3 = DecoderRNN(weights_matrix_eng, hidden_size, train_output_lang.n_words, n_layers = layers).to(device)
encoder3.load_state_dict(torch.load(folder_path + "/encoder3.pt",map_location='cpu'))
decoder3.load_state_dict(torch.load(folder_path +"/decoder3.pt",map_location='cpu'))

# %%
# Set to not-training mode to disable dropout
encoder3.train(False)
decoder3.train(False)

running_loss = 0
for l, (input_var,input_data_len,output_var,output_data_len) in enumerate(val_loader):
    input_batch = input_var.transpose(0,1).to(device)
    output_batch = output_var.transpose(0,1).to(device)
    encoder_outputs, encoder_hidden = encoder3(input_batch, input_data_len, None)
  
    max_target_length = MAX_LENGTH
    # Prepare decoder input and outputs
    decoder_input = Variable(torch.LongTensor([SOS_token] * BATCH_SIZE)).to(device)
    decoder_hidden = encoder_hidden[:decoder3.n_layers] # Use last (forward) hidden state from encoder
    all_decoder_outputs = Variable(torch.zeros(max_target_length, BATCH_SIZE, decoder3.output_size)).to(device)
  
    # Run through decoder one time step at a time
    for t in range(max_target_length):
        decoder_output, decoder_hidden = decoder3(
        decoder_input, decoder_hidden
    )
        
        topv, topi = decoder_output.topk(1)
        decoder_input = topi.squeeze().detach()  # detach from history as input
        all_decoder_outputs[t] = decoder_output # Store this step's outputs
    
    # Test masked cross entropy loss
    loss = masked_cross_entropy(
        all_decoder_outputs.transpose(0, 1).contiguous(),
        output_batch.transpose(0, 1).contiguous(),
        output_data_len)
    running_loss += loss

# %%
running_loss
# Out:
# tensor(5.5396, device='cuda:0', grad_fn=<DivBackward1>)

# %% [markdown]
# Calculate Bleu Score

# %%
from typing import List
from collections import Counter, namedtuple
from itertools import zip_longest

def tokenize_13a(line):
    """
    Tokenizes an input line using a relatively minimal tokenization that is however equivalent to mteval-v13a, used by WMT.
    :param line: a segment to tokenize
    :return: the tokenized line
    """

    norm = line

    # language-independent part:
    norm = norm.replace('<skipped>', '')
    norm = norm.replace('-\n', '')
    norm = norm.replace('\n', ' ')
    norm = norm.replace('&quot;', '"')
    norm = norm.replace('&amp;', '&')
    norm = norm.replace('&lt;', '<')
    norm = norm.replace('&gt;', '>')
    
    
        # language-dependent part (assuming Western languages):
    norm = " {} ".format(norm)
    norm = re.sub(r'([\{-\~\[-\` -\&\(-\+\:-\@\/])', ' \\1 ', norm)
    norm = re.sub(r'([^0-9])([\.,])', '\\1 \\2 ', norm)  # tokenize period and comma unless preceded by a digit
    norm = re.sub(r'([\.,])([^0-9])', ' \\1 \\2', norm)  # tokenize period and comma unless followed by a digit
    norm = re.sub(r'([0-9])(-)', '\\1 \\2 ', norm)  # tokenize dash when preceded by a digit
    norm = re.sub(r'\s+', ' ', norm)  # one space only between words
    norm = re.sub(r'^\s+', '', norm)  # no leading space
    norm = re.sub(r'\s+$', '', norm)  # no trailing space

    return norm

def corpus_bleu(sys_stream, ref_streams, smooth='exp', smooth_floor=0.0, force=False, lowercase=False,
                 use_effective_order=False):
    """Produces BLEU scores along with its sufficient statistics from a source against one or more references.
    :param sys_stream: The system stream (a sequence of segments)
    :param ref_streams: A list of one or more reference streams (each a sequence of segments)
    :param smooth: The smoothing method to use
    :param smooth_floor: For 'floor' smoothing, the floor to use
    :param force: Ignore data that looks already tokenized
    :param lowercase: Lowercase the data
    :param tokenize: The tokenizer to use
    :return: a BLEU object containing everything you'd want
    """

    # Add some robustness to the input arguments
    if isinstance(sys_stream, str):
        sys_stream = [sys_stream]
    if isinstance(ref_streams, str):
        ref_streams = [[ref_streams]]

    sys_len = 0
    ref_len = 0

    correct = [0 for n in range(NGRAM_ORDER)]
    total = [0 for n in range(NGRAM_ORDER)]
    

    # look for already-tokenized sentences
    tokenized_count = 0
    
    fhs = [sys_stream] + ref_streams
    for lines in zip_longest(*fhs):
        if None in lines:
            raise EOFError("Source and reference streams have different lengths!")

        if lowercase:
            lines = [x.lower() for x in lines]
            
        tokenize= 'tokenize_13a'    

        if not (force or tokenize == 'none') and lines[0].rstrip().endswith(' .'):
            tokenized_count += 1

            if tokenized_count == 100:
                logging.warning('That\'s 100 lines that end in a tokenized period (\'.\')')
                logging.warning('It looks like you forgot to detokenize your test data, which may hurt your score.')
                logging.warning('If you insist your data is detokenized, or don\'t care, you can suppress this message with \'--force\'.')

        output, *refs = [tokenize_13a(x.rstrip()) for x in lines]
        

        ref_ngrams, closest_diff, closest_len = ref_stats(output, refs)
        
        sys_len += len(output.split())
        ref_len += closest_len

        sys_ngrams = extract_ngrams(output)
        for ngram in sys_ngrams.keys():
            n = len(ngram.split())
            correct[n-1] += min(sys_ngrams[ngram], ref_ngrams.get(ngram, 0))
            total[n-1] += sys_ngrams[ngram]
            

    return compute_bleu(correct, total, sys_len, ref_len, smooth, smooth_floor, use_effective_order)
  
  
# n-gram order. Don't change this.
NGRAM_ORDER = 4

def compute_bleu(correct: List[int], total: List[int], sys_len: int, ref_len: int, smooth = 'none', smooth_floor = 0.01,
                 use_effective_order = False):
    """Computes BLEU score from its sufficient statistics. Adds smoothing.
    :param correct: List of counts of correct ngrams, 1 <= n <= NGRAM_ORDER
    :param total: List of counts of total ngrams, 1 <= n <= NGRAM_ORDER
    :param sys_len: The cumulative system length
    :param ref_len: The cumulative reference length
    :param smooth: The smoothing method to use
    :param smooth_floor: The smoothing value added, if smooth method 'floor' is used
    :param use_effective_order: Use effective order.
    :return: A BLEU object with the score (100-based) and other statistics.
    """

    precisions = [0 for x in range(NGRAM_ORDER)]

    smooth_mteval = 1.
    effective_order = NGRAM_ORDER
    for n in range(NGRAM_ORDER):
        if total[n] == 0:
            break

        if use_effective_order:
            effective_order = n + 1

        if correct[n] == 0:
            if smooth == 'exp':
                smooth_mteval *= 2
                precisions[n] = 100. / (smooth_mteval * total[n])
            elif smooth == 'floor':
                precisions[n] = 100. * smooth_floor / total[n]
        else:
            precisions[n] = 100. * correct[n] / total[n]

    # If the system guesses no i-grams, 1 <= i <= NGRAM_ORDER, the BLEU score is 0 (technically undefined).
    # This is a problem for sentence-level BLEU or a corpus of short sentences, where systems will get no credit
    # if sentence lengths fall under the NGRAM_ORDER threshold. This fix scales NGRAM_ORDER to the observed
    # maximum order. It is only available through the API and off by default

    brevity_penalty = 1.0
    if sys_len < ref_len:
        brevity_penalty = math.exp(1 - ref_len / sys_len) if sys_len > 0 else 0.0
        

    bleu = brevity_penalty * math.exp(sum(map(my_log, precisions[:effective_order])) / effective_order)

    return bleu 
  
def ref_stats(output, refs):
    ngrams = Counter()
    closest_diff = None
    closest_len = None
    for ref in refs:
        tokens = ref.split()
        reflen = len(tokens)
        diff = abs(len(output.split()) - reflen)
        if closest_diff is None or diff < closest_diff:
            closest_diff = diff
            closest_len = reflen
        elif diff == closest_diff:
            if reflen < closest_len:
                closest_len = reflen

        ngrams_ref = extract_ngrams(ref)
        for ngram in ngrams_ref.keys():
            ngrams[ngram] = max(ngrams[ngram], ngrams_ref[ngram])

    return ngrams, closest_diff, closest_len
  

def extract_ngrams(line, min_order=1, max_order=NGRAM_ORDER) -> Counter:
    """Extracts all the ngrams (1 <= n <= NGRAM_ORDER) from a sequence of tokens.
    :param line: a segment containing a sequence of words
    :param max_order: collect n-grams from 1<=n<=max
    :return: a dictionary containing ngrams and counts
    """

    ngrams = Counter()
    tokens = line.split()
    for n in range(min_order, max_order + 1):
        for i in range(0, len(tokens) - n + 1):
            ngram = ' '.join(tokens[i: i + n])
            ngrams[ngram] += 1

    return ngrams  
  


def my_log(num):
    """
    Floors the log function
    :param num: the number
    :return: log(num) floored to a very low number
    """

    if num == 0.0:
        return -9999999999
    return math.log(num)

# %%
def evaluate_batch(loader, encoder, decoder):
    
    decoded_sentences = []
    actual_sentences = []
    
    for i, (source, lengths1, target, lengths2) in enumerate(loader):
        #iterate over batch
        
        for n in range(len(source)):
            # Go sentence by sentence
            
            decoded, actual = evaluate(encoder, decoder, source[n].unsqueeze(0), lengths1[n], target[n])
            decoded_sentences.append(decoded)
            actual_sentences.append(actual)
            
    return decoded_sentences, actual_sentences


def evaluate_bleu(translation_list, reference_list):
    
    return corpus_bleu(translation_list, [reference_list])

# %%
class BeamSearchNode(object):
    def __init__(self, hiddenstate, previousNode, wordId, logProb, length):
        '''
        :param hiddenstate:
        :param previousNode:
        :param wordId:
        :param logProb:
        :param length:
        '''
        self.h = hiddenstate
        self.prevNode = previousNode
        self.wordid = wordId
        self.logp = logProb
        self.leng = length

# %%
def beam_decode(target_tensor, decoder_hiddens, encoder_outputs=None):
    '''
    :param target_tensor: target indexes tensor of shape [B, T] where B is the batch size and T is the maximum length of the output sentence
    :param decoder_hidden: input tensor of shape [1, B, H] for start of the decoding
    :param encoder_outputs: if you are using attention mechanism you can pass encoder outputs, [T, B, H] where T is the maximum length of input sentence
    :return: decoded_batch
    '''

    beam_width = 10
    topk = 1  # how many sentence do you want to generate
    decoded_batch = []

    # decoding goes sentence by sentence
    for idx in range(target_tensor.size(0)):
        if isinstance(decoder_hiddens, tuple):  # LSTM case
            decoder_hidden = (decoder_hiddens[0][:,idx, :].unsqueeze(0),decoder_hiddens[1][:,idx, :].unsqueeze(0))
        else:
            decoder_hidden = decoder_hiddens[:, idx, :].unsqueeze(0)
        encoder_output = encoder_outputs[:,idx, :].unsqueeze(1)

        # Start with the start of the sentence token
        decoder_input = torch.LongTensor([[SOS_token]], device=device)

        # Number of sentence to generate
        endnodes = []
        number_required = min((topk + 1), topk - len(endnodes))

        # starting node -  hidden vector, previous node, word id, logp, length
        node = BeamSearchNode(decoder_hidden, None, decoder_input, 0, 1)
        nodes = PriorityQueue()

        # start the queue
        nodes.put((-node.eval(), node))
        qsize = 1

        # start beam search
        while True:
            # give up when decoding takes too long
            if qsize > 2000: break

            # fetch the best node
            score, n = nodes.get()
            decoder_input = n.wordid
            decoder_hidden = n.h

            if n.wordid.item() == EOS_token and n.prevNode != None:
                endnodes.append((score, n))
                # if we reached maximum # of sentences required
                if len(endnodes) >= number_required:
                    break
                else:
                    continue

            # decode for one step using decoder
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden, encoder_output)

            # PUT HERE REAL BEAM SEARCH OF TOP
            log_prob, indexes = torch.topk(decoder_output, beam_width)
            nextnodes = []

            for new_k in range(beam_width):
                decoded_t = indexes[0][new_k].view(1, -1)
                log_p = log_prob[0][new_k].item()

                node = BeamSearchNode(decoder_hidden, n, decoded_t, n.logp + log_p, n.leng + 1)
                score = -node.eval()
                nextnodes.append((score, node))

            # put them into queue
            for i in range(len(nextnodes)):
                score, nn = nextnodes[i]
                nodes.put((score, nn))
                # increase qsize
            qsize += len(nextnodes) - 1

        # choose nbest paths, back trace them
        if len(endnodes) == 0:
            endnodes = [nodes.get() for _ in range(topk)]

        utterances = []
        for score, n in sorted(endnodes, key=operator.itemgetter(0)):
            utterance = []
            utterance.append(n.wordid)
            # back trace
            while n.prevNode != None:
                n = n.prevNode
                utterance.append(n.wordid)

            utterance = utterance[::-1]
            utterances.append(utterance)

        decoded_batch.append(utterances)

    return decoded_batch

# %%
# Configure models
hidden_size = 500
layers = 2
teacher_forcing_ratio = 0.5
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iters = 10000

encoder3 = EncoderRNN(weights_matrix_zh, train_input_lang.n_words, hidden_size, n_layers = layers).to(device)
decoder3 = DecoderRNN(weights_matrix_eng, hidden_size, train_output_lang.n_words, n_layers = layers).to(device)
encoder3.load_state_dict(torch.load(folder_path + "/encoder3.pt",map_location='cpu'))
decoder3.load_state_dict(torch.load(folder_path +"/decoder3.pt",map_location='cpu'))

# %%
decoded, actual = evaluate_batch(val_loader, encoder3, decoder3)

for i in zip(decoded, actual):
    if i == 10:
        break
    print('\n')
    print('Expected:', i[1])
    print('Actual:' ,i[0])
# Out:
# /Users/Stella/miniconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# Expected:  She retired two years ago only to turn our house into a school for girls and women in our neighborhood .
# Actual:  She was years to years ago ago .
#
#
# Expected:  There was a big smile on his face which was unusual then because the news mostly depressed him .
# Actual:  He s .
#
#
# Expected:  And my father that s him he was the first ever in his family to receive an education .
# Actual:  My mother was my mother .
#
#
# Expected:  We all knew we were risking our lives the teacher the students and our parents .
# Actual:  We all all all all all .
#
#
# Expected:  When I was I remember waking up one morning to the sound of joy in my house .
# Actual:  I was years to . . . .
#
#
# Expected:  I didn t know what it meant but I could see that my father was very very happy .
# Actual:  I don t know it .
#
#
# Expected:  You see I was six when the Taliban took over Afghanistan and made it illegal for girls to go to school .
# Actual:  My father was to to . . .
#
#
# Expected:  Each day we took a different route so that no one would suspect where we were going .
# Actual:  We have to to to to . .
#
#
# Expected:  We would cover our books in grocery bags so it would seem we were just out shopping .
# Actual:  We re going to on on on the the the . . .
#
#
# Expected:  The school was in a house more than of us packed in one small living room .
# Actual:  The is the the the the the . . .
#
#
# Expected:  I was very lucky to grow up in a family where education was prized and daughters were treasured .
# Actual:  I was really .
#
#
# Expected:  My father was listening to BBC News on his small gray radio .
# Actual:  My mother was my mother .
#
#
# Expected:  You can go to a real school now he said .
# Actual:  You can you to to you you .
#
#
# Expected:  From time to time the school would suddenly be canceled for a week because Taliban were suspicious .
# Actual:  And a a of a . . . . .
#
#
# Expected:  To him there was greater risk in not educating his children .
# Actual:  It s to
#
#
# Expected:  Your money can be stolen . You can be forced to leave your home during a war .
# Actual:  You would be be your be be a . .
#
#
# Expected:  I was raised in a country that has been destroyed by decades of war .
# Actual:  My life is my life .
#
#
# Expected:  We were scared but still school was where we wanted to be .
# Actual:  We re really .
#
#
# Expected:  Instead I stand here a proud graduate of Middlebury College .
# Actual:  And now I ve been now now now now now .
#
#
# Expected:  The Taliban are gone ! my father shouted .
# Actual:  And the was a . .
#
#
# Expected:  My grandfather was an extraordinary man for his time .
# Actual:  My mother was my father .
#
#
# Expected:  But my educated mother became a teacher .
# Actual:  But my was my was . .
#
#
# Expected:  It was the only way we both could be educated .
# Actual:  That s them us for them for us .
#
#
# Expected:  It was cozy in winter but extremely hot in summer .
# Actual:  It was pretty .
#
#
# Expected:  We always wondered what they knew about us .
# Actual:  We don be be be to be be . . .
#
#
# Expected:  So do you still not want to continue ?
# Actual:  But you you you you you you you you you you
#
#
# Expected:  A morning that I will never forget .
# Actual:  I I t never never never .
#
#
# Expected:  Do they know where we live ?
# Actual:  They are our our . .
#
#
# Expected:  Were we being followed ?
# Actual:  We re our in our the . . . .
#
#
# Expected:  A real school .
# Actual:  The is is the the . . .
#
#
# Expected:  Today I am .
# Actual:  And I was to to . .
#
#
# Expected:  There she is .
# Actual:  That s she .
#
#
# Expected:  I worked for an Italian NGO and every single project that we set up in Africa failed .
# Actual:  I was in the .
#
#
# Expected:  That s why I am a global ambassador for x a global campaign to educate women .
# Actual:  That is the I I I I .
#
#
# Expected:  I thought age that we Italians were good people and we were doing good work in Africa .
# Actual:  And was was at the . .
#
#
# Expected:  And we could not believe and we were telling the Look how easy agriculture is .
# Actual:  That s really .
#
#
# Expected:  I treat anybody from a different culture as if they were my children . I love you so much .
# Actual:  The is .
#
#
# Expected:  The exciting thing is that I see students at my school with ambition grabbing at opportunity .
# Actual:  So me me me to me .
#
#
# Expected:  We Western donor countries have given the African continent two trillion American dollars in the last years .
# Actual:  And our our our the of of the . .
#
#
# Expected:  But instead of asking them how come they were not growing anything we simply said Thank God we re here .
# Actual:  But we have no no no not t . .
#
#
# Expected:  And we were amazed that the local people in such a fertile valley would not have any agriculture .
# Actual:  It are a very very . .
#
#
# Expected:  And the said Yes that s why we have no agriculture here .
# Actual:  The people said say .
#
#
# Expected:  Read it from an African woman the damage that we have done .
# Actual:  Look at a .
#
#
# Expected:  And we said to the My God the !
# Actual:  We re in the the .
#
#
# Expected:  The two words come from the Latin root which means father .
# Actual:  This is from the the of the from the .
#
#
# Expected:  I dream big but my family dreams even bigger for me .
# Actual:  My life has been important for life .
#
#
# Expected:  Why didn t you tell us ? You never asked .
# Actual:  Why ?
#
#
# Expected:  But today more than three million girls are in school in Afghanistan .
# Actual:  But today .
#
#
# Expected:  I find that Americans see the fragility in changes .
# Actual:  I I found .
#
#
# Expected:  It s not to say that our mothers aren t key in our success .
# Actual:  That s not not not say it ?
#
#
# Expected:  I fear that these changes will not last much beyond the U . troops withdrawal .
# Actual:  And I I these these these are going to change .
#
#
# Expected:  Just in the nick of time to save the Zambian people from starvation .
# Actual:  in the the of .
#
#
# Expected:  And of course everything in Africa grew beautifully .
# Actual:  But course is in the time .
#
#
# Expected:  I m not going to tell you the damage that that money has done .
# Actual:  I want to want to want to be like .
#
#
# Expected:  Like me they are dreaming big .
# Actual:  It like like like like like like like like like like like like like like like .
#
#
# Expected:  My family believes in me .
# Actual:  .
#
#
# Expected:  Afghanistan looks so different from here in America .
# Actual:  .
#
#
# Expected:  Instead everything we touched we killed .
# Actual:  But we we we we we we we we we
#
#
# Expected:  Because you see at least we fed the .
# Actual:  So we we we we we we we we we we
#
#
# Expected:  The book was published in .
# Actual:  It was a in for the the in the . .
#
#
# Expected:  But they mean two different things .
# Actual:  But the is the the . .
#
#
# Expected:  And I was distraught .
# Actual:  I I I I .
#
#
# Expected:  Just go and read her book .
# Actual:  You want to to .
#
#
# Expected:  Thank you .
# Actual:  Thank you .
#
#
# Expected:  Peter one of the greatest management consultants in history died age a few years ago .
# Actual:
#
#
# Expected:  And then we help them to go and find the knowledge because nobody in the world can succeed alone .
# Actual:  And they they them them them them they re going to them .
#
#
# Expected:  You never arrive in a community with any ideas and you sit with the local people .
# Actual:  And we re to in the the the the the
#
#
# Expected:  The people in your community you don t even know because they don t come to your public meetings .
# Actual:  You don t t t you you . .
#
#
# Expected:  I was a doing a . at the time trying to go away from this patronizing bullshit that we arrive and tell you what to do .
# Actual:  And I was I to the .
#
#
# Expected:  So So the government says Do it again .
# Actual:  So so .
#
#
# Expected:  And what we do we become friends and we find out what that person wants to do .
# Actual:  And do what do do do do ?
#
#
# Expected:  How can you do ? And I said I do something very very very difficult .
# Actual:  How do you do it ?
#
#
# Expected:  The passion that that man has for his own personal growth is the most important thing .
# Actual:  The is is is is .
#
#
# Expected:  I treat everybody from another culture as if they were my servants .
# Actual:  I I I I I I I I I
#
#
# Expected:  That s why the white people in Africa are called boss .
# Actual:  That s why it s ?
#
#
# Expected:  There is a new generation of entrepreneurs who are dying of solitude .
# Actual:  a .
#
#
# Expected:  The person with the idea may not have the knowledge but the knowledge is available .
# Actual:  But people are a like like like a little little like .
#
#
# Expected:  I started this as a in in Western Australia .
# Actual:  I m in the . .
#
#
# Expected:  If that person doesn t want to do it what are you going to do ?
# Actual:  But if if it is
#
#
# Expected:  The passion that the person has for her own growth is the most important thing .
# Actual:  The is is to with with us .
#
#
# Expected:  We ve done it in communities around the world .
# Actual:  We world world world world world world world world .
#
#
# Expected:  So what you do you shut up .
# Actual:  So we do we do do we do do it do ? do do ? do ? do ? do ? do ? do ? do ? ?
#
#
# Expected:  We have helped to start businesses .
# Actual:  We have to to to . . . .
#
#
# Expected:  We don t work from offices .
# Actual:  The our our our our our . .
#
#
# Expected:  We meet at the cafe . We meet at the pub .
# Actual:  We re in our the with . .
#
#
# Expected:  We have zero infrastructure .
# Actual:  We have no have no . . .
#
#
# Expected:  You can give somebody an idea .
# Actual:  You can our our our our our .
#
#
# Expected:  I shut up and listen to them .
# Actual:  That s the .
#
#
# Expected:  This should be the first principle of aid .
# Actual:  It s a to the the . .
#
#
# Expected:  You have to create a new profession .
# Actual:  We need to to .
#
#
# Expected:  Planning is the kiss of death of entrepreneurship .
# Actual:  The is is the the the the
#
#
# Expected:  The first principle of aid is respect .
# Actual:  The is the the the the the the the .
#
#
# Expected:  So planning has this blind spot .
# Actual:  So there there s a lot for this do .
#
#
# Expected:  The most important thing is passion .
# Actual:  And is is important important important .
#
#
# Expected:  Let me tell you a secret .
# Actual:  I m tell you
#
#
# Expected:  There is a problem with community meetings .
# Actual:  The is a a .
#
#
# Expected:  The idea of finding a different technology had absolutely taken over and there were tiny tiny little factories in .
# Actual:  is a the the the . . . .
#
#
# Expected:  Who is going to invent the technology for the green revolution ? Universities ? Forget about it !
# Actual:  And this this this this this this this ? ? this this ?
#
#
# Expected:  There s a lovely story that I read in a magazine many many years ago .
# Actual:  years years ago ago ago ago ago ago ago ago ago ago ago ago ago ago ago ago ago ago ago ago .
#
#
# Expected:  We have never met a single human being in the world who can make it sell it and look after the money .
# Actual:  That s never never never never never never never .
#
#
# Expected:  So they are seeing this dirty technology that is going to choke the life out of New York .
# Actual:  So it s .
#
#
# Expected:  Can you imagine a community of people the intelligence and the passion ?
# Actual:  You can you
#
#
# Expected:  There was a group of experts who were invited to discuss the future of the city of New York in .
# Actual:  .
#
#
# Expected:  So what I m saying is that entrepreneurship is where it s at .
# Actual:  So I want to tell it .
#
#
# Expected:  Never the word I and the word we times .
# Actual:  I I I I I . .
#
#
# Expected:  In a community of people we get clients .
# Actual:  It .
#
#
# Expected:  You have to learn how to get these people to come and talk to you .
# Actual:  How do we do we do we do ? ? ? ? ? ?
#
#
# Expected:  Local passionate people . That s who you have applauded .
# Actual:  It s a with a .
#
#
# Expected:  It will be entrepreneurs and they re doing it now .
# Actual:  The is the the the the . .
#
#
# Expected:  Okay can you sell it ? Can you look after the money ?
# Actual:  You can be a for for a time for a time for a time .
#
#
# Expected:  Which presentation have you applauded the most this morning ?
# Actual:  Today today today today today today today today today .
#
#
# Expected:  Dearborn Michigan . Henry Ford .
# Actual:  .
#
#
# Expected:  However there is a secret to work with entrepreneurs .
# Actual:  But the is with the the .
#
#
# Expected:  Then you have to offer them absolute dedicated passionate service to them .
# Actual:  They they them them them they re going to them .
#
#
# Expected:  What can you do ? Can you make it ?
# Actual:  What do you do do ? ? ? ? ?
#
#
# Expected:  The internal combustion engine is not sustainable .
# Actual:  The is the the . . .
#
#
# Expected:  way of maintaining things is not sustainable .
# Actual:  the for the .
#
#
# Expected:  First you have to offer them confidentiality .
# Actual:  And you you you you you you you you you you
#
#
# Expected:  Nobody started a company alone . No one .
# Actual:  It s not be to be . .
#
#
# Expected:  The technologies do not exist to do that .
# Actual:  The is is have to the the . . . .
#
#
# Expected:  And then you have to tell them the truth about entrepreneurship .
# Actual:  And they want them them they re going to them ?
#
#
# Expected:  They were already drowning in manure .
# Actual:  So people people people people people .
#
#
# Expected:  Otherwise they don t come and talk to you .
# Actual:  They would t .
#
#
# Expected:  Government ? Forget about it !
# Actual:  ?
#
#
# Expected:  He wasn t alone when he started .
# Actual:  And he was when he was going to be a time .
#
#
# Expected:  This person has never been born .
# Actual:  So there was no much have have been have been been a time .
#
#
# Expected:  Guess what ?
# Actual:  So why question ?
#
#
# Expected:  It doesn t exist .
# Actual:  And this is is a a . . .
#
#
# Expected:  A slide like this is not only boring but it relies too much on the language area of our brain and causes us to become overwhelmed .
# Actual:  It like like like like like this ?
#
#
# Expected:  And it was only a few years later that we have the first recorded use of the phrase as bold as brass .
# Actual:  And it s not .
#
#
# Expected:  Penn State asked me a communications teacher to teach a communications class for engineering students .
# Actual:  .
#
#
# Expected:  We desperately need great communication from our scientists and engineers in order to change the world .
# Actual:  They change to change world .
#
#
# Expected:  Instead as Einstein said make everything as simple as possible but no simpler .
# Actual:  And as as it s not just like .
#
#
# Expected:  And they had to face the question of what to call George Washington their leader .
# Actual:  They were a . .
#
#
# Expected:  What do bullets do ? Bullets kill and they will kill your presentation .
# Actual:  What are what what is ? ? ? ? ?
#
#
# Expected:  Oh no I cannot do this . Would you like me to find you somebody ?
# Actual:  And this this this is this this this this this .
#
#
# Expected:  So scientists and engineers please talk nerdy to us .
# Actual:  So the the . .
#
#
# Expected:  You can clearly communicate your science without compromising the ideas .
# Actual:  You don t to change to change to change change to change ?
#
#
# Expected:  And when presenting your work drop the bullet points .
# Actual:  And there s some .
#
#
# Expected:  One of my favorite words in the whole of the Oxford English Dictionary is .
# Actual:  I love me .
#
#
# Expected:  And I believe the key to opening that door is great communication .
# Actual:  I I it it it .
#
#
# Expected:  Five years ago I experienced a bit of what it must have been like to be Alice in Wonderland .
# Actual:  years ago ago ago ago ago ago ago ago ago ago .
#
#
# Expected:  Have you ever wondered why they re called bullet points ?
# Actual:  And you want to want to ?
#
#
# Expected:  First question to answer for us so what ?
# Actual:  The first first first is going to be first .
#
#
# Expected:  It s not . It s down to a campaigner for the freedom of the press .
# Actual:  It s not not .
#
#
# Expected:  And when you re describing your science beware of jargon .
# Actual:  And you you you to you you you
#
#
# Expected:  Now I have no idea what is .
# Actual:  I I I I
#
#
# Expected:  Something to do with words I assume .
# Actual:  It s a about with the .
#
#
# Expected:  Tell us why your science is relevant to us .
# Actual:  Let s us .
#
#
# Expected:  And making your ideas accessible is not the same as it down .
# Actual:  So your your things for your things .
#
#
# Expected:  And what means is a dishonest politician .
# Actual:  And it s not it .
#
#
# Expected:  Most people think that s down to the metal .
# Actual:  And this this this this this this this this this this this .
#
#
# Expected:  is a barrier to our understanding of your ideas .
# Actual:  The is is is that we re we to
#
#
# Expected:  What do you call the leader of a republican country ?
# Actual:  It s a the the the
#
#
# Expected:  Just because it sounds so good .
# Actual:  It it it it .
#
#
# Expected:  We activate communities .
# Actual:  We re to to the the of of the .
#
#
# Expected:  Thank you .
# Actual:  Thank you .
#
#
# Expected:  Thank you .
# Actual:  Thank you .
#
#
# Expected:  And I was scared .
# Actual:  I ve got up . .
#
#
# Expected:  They didn t know .
# Actual:  They don t know .
#
#
# Expected:  So they wanted to give him the most pathetic title that they could think of .
# Actual:  So they he him him .
#
#
# Expected:  And they weren t even being there they had the idea that you could be elected King for a fixed term .
# Actual:  They don t have not have not have . .
#
#
# Expected:  And everybody got insanely bored actually because this debate went on for three weeks .
# Actual:  And it s a . . .
#
#
# Expected:  All because they want to sound like the guy who s got the nuclear warheads etc .
# Actual:  It s not because it s not .
#
#
# Expected:  And that s the important lesson I think you can take away and the one I want to leave you with .
# Actual:  That it is not very much .
#
#
# Expected:  I read a diary of this poor senator who just keeps coming back Still on this subject .
# Actual:  I I I
#
#
# Expected:  They didn t want to call him King in case that gave him ideas or his successor ideas .
# Actual:  They want to want him him him .
#
#
# Expected:  And it didn t have much more grandeur than the term foreman or overseer .
# Actual:  It also be be . . . .
#
#
# Expected:  And try and use this campaign to expose these who are as national heroes .
# Actual:  I I to to the the the the . . .
#
#
# Expected:  And the reason for the delay and the boredom was that the House of Representatives were against the Senate .
# Actual:  It was not to and with with them .
#
#
# Expected:  And after three weeks of debate in the end the Senate did not cave in .
# Actual:  But then was a . . .
#
#
# Expected:  They said that s ridiculous you can t call him President .
# Actual:  They they really really really really .
#
#
# Expected:  But now do you know how many nations have a president ?
# Actual:  But now now .
#
#
# Expected:  And there were all sorts of suggestions on the table which might have made it .
# Actual:  It many lot lot lot of many lot lot of them .
#
#
# Expected:  They thought it was tried and tested .
# Actual:  They re a a . . .
#
#
# Expected:  And that s why the Senate objected to it .
# Actual:  That it is not be .
#
#
# Expected:  Now you can learn three interesting things from this .
# Actual:  So this s this story today today .
#
#
# Expected:  The House of Representatives didn t want Washington to get drunk on power .
# Actual:  No don t want to want to want to want to want to want to want .
#
#
# Expected:  And this was debated in Congress for ages and ages .
# Actual:  So this is in this problem in this problem .
#
#
# Expected:  This guy has to go and sign treaties and meet foreign dignitaries .
# Actual:  That this s not this .
#
#
# Expected:  Reality and history have endowed that title with grandeur .
# Actual:  It is to be with with the time of the change .
#
#
# Expected:  And you know it could have worked .
# Actual:  You know know .
#
#
# Expected:  They got their title of respectability .
# Actual:  They they them them their . . .
#
#
# Expected:  And this was my first time in Afghanistan .
# Actual:  That first first first first first .
#
#
# Expected:  Not that catchy .
# Actual:  No no no .
#
#
# Expected:  Some people just wanted to call him King .
# Actual:  Some people want to want to me .
#
#
# Expected:  And that title was President .
# Actual:  And the the the the .
#
#
# Expected:  It was like the foreman of the jury .
# Actual:  It was the the the . .
#
#
# Expected:  And so the Senate won in the end .
# Actual:  So the the the . .
#
#
# Expected:  But this is the geography of self .
# Actual:  But this is not just do that do this .
#
#
# Expected:  Thank you very much .
# Actual:  Thank you very much .
#
#
# Expected:  A hundred and forty seven .
# Actual:  .
#
#
# Expected:  If some of the women were really horrified when I came out you don t have to tell me now but I ll find out later on Twitter .
# Actual:  And if if people have a lot of this .
#
#
# Expected:  I am on this stage because I am a pretty white woman and in my industry we call that a sexy girl .
# Actual:  I m this the the the the the the the
#
#
# Expected:  And I feel like there s an uncomfortable tension in the room right now because I should not have worn this dress .
# Actual:  Now I I I I I I
#
#
# Expected:  I was totally uncomfortable and the photographer was telling me to arch my back and put my hand in that guy s hair .
# Actual:  When the .
#
#
# Expected:  And the first answer is I don t know they don t put me in charge of that .
# Actual:  My first first .
#
#
# Expected:  This is the first outfit change on the TED stage so you guys are pretty lucky to witness it I think .
# Actual:  And this is the the the the
#
#
# Expected:  I d also note that I m quite privileged to be able to transform what you think of me in a very brief seconds .
# Actual:  And I want to tell you tell it s going to tell you .
#
#
# Expected:  Hi . My name is Cameron Russell and for the last little while I ve been a model .
# Actual:  I I I I I I
#
#
# Expected:  And I always just say Oh I was but that means nothing .
# Actual:  I I say .
#
#
# Expected:  I want to look at how in my opinion the conflict in Afghanistan has become conflict chic .
# Actual:  I want to to to it with this ?
#
#
# Expected:  The next question people always ask me is Can I be a model when I grow up ?
# Actual:  The people people people people people people people people .
#
#
# Expected:  And in this picture I had actually never had a boyfriend in real life .
# Actual:  This is a picture of the picture .
#
#
# Expected:  But I do them because I have to because the geography of self mandates it .
# Actual:  But I I I I I I
#
#
# Expected:  And I m going to answer the questions that people always ask me but with an honest twist .
# Actual:  I I want to do .
#
#
# Expected:  These heels are very uncomfortable so good thing I wasn t going to wear them .
# Actual:  It was very very very . .
#
#
# Expected:  I just totally transformed what you thought of me in six seconds .
# Actual:  I m only only .
#
#
# Expected:  So today for me being fearless means being honest .
# Actual:  So now s .
#
#
# Expected:  But doing these things they can get you in jail they can be misunderstood misinterpreted .
# Actual:  But these do these do this do this do this do this do this do this ?
#
#
# Expected:  And this is a legacy that was built for me and it s a legacy that I ve been out on .
# Actual:  That is my my my .
#
#
# Expected:  And first I commend you on your model knowledge . Very impressive .
# Actual:  So I I I I I I I
#
#
# Expected:  So why did I do that ?
# Actual:  So I I I I I I
#
#
# Expected:  Image is powerful but also image is superficial .
# Actual:  It are a very simple . It are the brain .
#
#
# Expected:  So the first question is how do you become a model ?
# Actual:  The question question is the question question question .
#
#
# Expected:  And I am on this stage because I am a model .
# Actual:  I m going today today today today today today today today today today today .
#
#
# Expected:  That is my burden . What s yours ?
# Actual:  That is my my my .
#
#
# Expected:  Actually for years .
# Actual:  It s a .
#
#
# Expected:  Not everybody gets to do that .
# Actual:  That s not not .
#
#
# Expected:  Well hopefully not as awkward as that picture .
# Actual:  Well I want to want to want to be .
#
#
# Expected:  So luckily I brought an outfit change .
# Actual:  And I had my time .
#
#
# Expected:  That was awkward .
# Actual:  It s a .
#
#
# Expected:  All right .
# Actual:  It can be
#
#
# Expected:  Thank you .
# Actual:  Thank you .
#
#
# Expected:  I will demonstrate for you now years of accumulated model knowledge because unlike thoracic surgeons it can just be distilled right into right now .
# Actual:  Thank I m you you you you you you you
#
#
# Expected:  We say It s really amazing to travel and it s amazing to get to work with creative inspired passionate people .
# Actual:  We said say .
#
#
# Expected:  It s out of your control and it s awesome and it s not a career path .
# Actual:  It can be be be be a be a be a . . .
#
#
# Expected:  But the second answer and what I really want to say to these little girls is Why ?
# Actual:  But the first .
#
#
# Expected:  I grew up in Cambridge and one time I went into a store and I forgot my money and they gave me the dress for free .
# Actual:  I was in the . .
#
#
# Expected:  But mostly it was difficult to a legacy of gender and racial oppression when I am one of the biggest beneficiaries .
# Actual:  But it is is is the is .
#
#
# Expected:  And if you ever are wondering If I have thinner thighs and hair will I be happier ?
# Actual:  And if you have be be a .
#
#
# Expected:  And yeah they pretty much all the photos but that is only a small component of what s happening .
# Actual:  It s a .
#
#
# Expected:  Saying that you want to be a model when you grow up is akin to saying that you want to win the when you grow up .
# Actual:  And you you you you you .
#
#
# Expected:  The next question people always ask me is Do they all the photos ?
# Actual:  The people people people people people people people people .
#
#
# Expected:  Here s me at a slumber party a few days before I shot French Vogue .
# Actual:  That s me .
#
#
# Expected:  but How many times will I get stopped ? When will I get stopped ?
# Actual:  It I I I I I I I I
#
#
# Expected:  I know we re getting personal but I was a young girl .
# Actual:  And I I like it this is this like this ?
#
#
# Expected:  And when we re backstage we give an answer that maybe makes it seem like that .
# Actual:  The the .
#
#
# Expected:  And I m insecure because I have to think about what I look like every day .
# Actual:  Because I have to be be a day every day every day .
#
#
# Expected:  This is what I looked like with my grandma just a few months earlier .
# Actual:  That this is the picture .
#
#
# Expected:  And I hope what you re seeing is that these pictures are not pictures of me .
# Actual:  And I want you know you know you know you know you know you
#
#
# Expected:  Okay so the next question people always ask me is Do you get free stuff ?
# Actual:  The is is is is is is is the
#
#
# Expected:  So the last question people ask me is What is it like to be a model ?
# Actual:  So the problem question is a problem problem ?
#
#
# Expected:  Here s me on the soccer team and in V Magazine .
# Actual:  That is me here here .
#
#
# Expected:  You know ? You can be anything .
# Actual:  Do you know it ?
#
#
# Expected:  That was I don t know what happened there .
# Actual:  I don t know it .
#
#
# Expected:  Now I d like to introduce you to my brothers .
# Actual:  And I want to give you to give a little of the .
#
#
# Expected:  is tall and very handsome .
# Actual:  And years to .
#
#
# Expected:  Hopefully less awkward than that one in the middle .
# Actual:  It s just a be a a like the . . . .
#
#
# Expected:  It will look something like this .
# Actual:  This looks out that looks like it looks .
#
#
# Expected:  Please don t tell me I m normal .
# Actual:  I m not it me me me .
#
#
# Expected:  Here s me on the same day as this shoot .
# Actual:  This is the the .
#
#
# Expected:  My friend got to come with me .
# Actual:  My mother I m me to me my my .
#
#
# Expected:  Today I have just one request .
# Actual:  I I to to to do .
#
#
# Expected:  And here s me today .
# Actual:  That is the the . .
#
#
# Expected:  Thank you .
# Actual:  Thank you .
#
#
# Expected:  Now if you take that bullet and take this packet of photons and fire into this bottle how will those photons shatter into this bottle ?
# Actual:  Now if if if if you you you ?
#
#
# Expected:  He didn t want to play like the other babies did and in fact he didn t seem very interested in me whatsoever .
# Actual:  It doesn t like like like like like like like like like like like ?
#
#
# Expected:  And if I could communicate just one thing to and to Sam and to you it would be that you don t have to be normal .
# Actual:  And I want to want to say it ?
#
#
# Expected:  So the pulse enters the bottle our bullet with a packet of photons that start traveling through and that start scattering inside .
# Actual:  Now now is the the the
#
#
# Expected:  He s speechless but he communicates joy in a way that some of the best cannot .
# Actual:  He s not
#
#
# Expected:  I was just three years old when my brother came along and I was so excited that I had a new being in my life .
# Actual:  I have when I was when I was going at the time .
#
#
# Expected:  overlooks the beauty that differences give us and the fact that we are different doesn t mean that one of us is wrong .
# Actual:  It is not not not . . .
#
#
# Expected:  The chance for greatness for progress and for change dies the moment we try to be like someone else .
# Actual:  is a us for us .
#
#
# Expected:  He doesn t care about religious differences and get this He has never told a lie .
# Actual:  And he s not not .
#
#
# Expected:  It manifests in each individual differently hence why is so different from Sam .
# Actual:  And every day with a day .
#
#
# Expected:  Now I cannot deny that there have been some challenging moments in my family moments where I ve wished that they were just like me .
# Actual:  I don t no
#
#
# Expected:  Now there s a lot going on in this movie so let me break this down and show you what s going on .
# Actual:  Now now in in the time .
#
#
# Expected:  Some of the light leaks goes on the table and you start seeing these ripples of waves .
# Actual:  And some of some things .
#
#
# Expected:  And as he grew older he grew more different and the differences became more obvious .
# Actual:  And he was it .
#
#
# Expected:  And after a few months went by I realized that he was different .
# Actual:  And it s .
#
#
# Expected:  He s not greedy . He doesn t see skin color .
# Actual:  He s not
#
#
# Expected:  He shares it unconditionally and he shares it regardless .
# Actual:  And he was
#
#
# Expected:  Samuel is . He s tall . He s very handsome .
# Actual:  years ago .
#
#
# Expected:  Now the whole event
# Actual:  Now now s now .
#
#
# Expected:  It just means that there s a different kind of right .
# Actual:  But just just just just just just just .
#
#
# Expected:  He has a selective one though .
# Actual:  But this is a the .
#
#
# Expected:  How does light look in slow motion ?
# Actual:  The is in the .
#
#
# Expected:  But Cola did not sponsor this research .
# Actual:  But .
#
#
# Expected:  Please don t tell me I m normal .
# Actual:  I me me me me me me me me me .
#
#
# Expected:  He has the most impeccable memory .
# Actual:  It was a very life for his life .
#
#
# Expected:  But most people don t agree .
# Actual:  But people don t have much much .
#
#
# Expected:  You can be extraordinary .
# Actual:  You can be a . . .
#
#
# Expected:  knows what love is .
# Actual:  And what is it ?
#
#
# Expected:  Don t they sound incredible ?
# Actual:  It s really very pretty pretty pretty pretty .
#
#
# Expected:  Thank you .
# Actual:  Thank you .
#
#
# Expected:  Extraordinary .
# Actual:  It it is not .
#
#
# Expected:  He screamed a lot .
# Actual:  And he was a .
#
#
# Expected:  Some other heroes can become invisible but what about a new power for a future superhero to see around corners ?
# Actual:  Some can can can can can other other other .
#
#
# Expected:  So how did my team at MIT create this camera ?
# Actual:  So I I I I I I
#
#
# Expected:  And we can take all that raw data and treat it in very interesting ways .
# Actual:  And all all all all all all all all all all .
#
#
# Expected:  This is where I live . I live in Kenya at the south parts of the Nairobi National Park .
# Actual:  That is my my .
#
#
# Expected:  Those are my dad s cows at the back and behind the cows that s the Nairobi National Park .
# Actual:  I was my my my
#
#
# Expected:  So predators like lions follow them and this is what they do .
# Actual:  So this like this like this like this like this like this ?
#
#
# Expected:  You can watch the ripples again washing over the table the tomato and the wall in the back .
# Actual:  And you could be it .
#
#
# Expected:  It has very good time resolution and it can look at the world at the speed of light .
# Actual:  It s pretty pretty .
#
#
# Expected:  As you can see there s a bubble of air and it s bouncing around inside .
# Actual:  You can see see that .
#
#
# Expected:  It ll be a very boring movie of a slow ordinary bullet in motion .
# Actual:  That it s really be very much .
#
#
# Expected:  There s a hidden behind a wall and we re going to bounce light off the door .
# Actual:  The the the .
#
#
# Expected:  When you look at the ripples under the cap the ripples are moving away from us .
# Actual:  And these these these these these these these these these .
#
#
# Expected:  It s one of the six lions which were killed in Nairobi .
# Actual:  This is all the all of them .
#
#
# Expected:  Many of the photons eventually reach the cap and then they explode in various directions .
# Actual:  The lot of of .
#
#
# Expected:  And it s not science fiction . We have actually built it .
# Actual:  That not not not not not not not not not not not not not not not ?
#
#
# Expected:  And I think this is why the Nairobi National Park lions are few .
# Actual:  And I want this is this is this .
#
#
# Expected:  It s about time . Thank you .
# Actual:  It s not much much much much much much much much much much much .
#
#
# Expected:  A day a week ? Actually a whole year .
# Actual:  And .
#
#
# Expected:  On the left you see our camera .
# Actual:  The right is the .
#
#
# Expected:  So this is our reconstruction .
# Actual:  That is our our . .
#
#
# Expected:  It s like throwing a stone in a pond of water .
# Actual:  That s just like it in the time .
#
#
# Expected:  The idea is that we could shine some light on the door .
# Actual:  So we re we we we we we re our
#
#
# Expected:  So I had to find a way of solving this problem .
# Actual:  So I I to to be I I to . . . . .
#
#
# Expected:  So I grew up hating lions so much .
# Actual:  So I I I
#
#
# Expected:  And what about some still life photography ?
# Actual:  But some of some of a . .
#
#
# Expected:  But there s also something funny going on here .
# Actual:  And some things are things things are things .
#
#
# Expected:  The ripples should be moving towards us .
# Actual:  But they are are going to be .
#
#
# Expected:  So they kill the lions .
# Actual:  So they would to to . .
#
#
# Expected:  So Superman can fly .
# Actual:  Now now a .
#
#
# Expected:  Can we see it in full D ?
# Actual:  We can have a . . .
#
#
# Expected:  They kill our livestock .
# Actual:  And we re we we we us us . .
#
#
# Expected:  What s going on here ?
# Actual:  What ?
#
#
# Expected:  She had a lot of her animals being killed by lions and she asked me if I could put the lights for her .
# Actual:  She was a . .
#
#
# Expected:  Ashe . It means in my language thank you very much .
# Actual:  Thank you very much .
#
#
# Expected:  Since now I ve set up seven homes around my community and they re really working .
# Actual:  Now .
#
#
# Expected:  So one night I was walking around the with a torch and that day the lions didn t come .
# Actual:  And there .
#
#
# Expected:  But I came to realize that that didn t really help because it was even helping the lions to see through the .
# Actual:  But I had to be a . .
#
#
# Expected:  So my big dream is to become an aircraft engineer and pilot when I grow up .
# Actual:  So my my life .
#
#
# Expected:  My new school now is coming in and helping by fundraising and creating an awareness .
# Actual:  My my my my . .
#
#
# Expected:  You have no idea how exciting it is to hear a story like yours .
# Actual:  .
#
#
# Expected:  And the first idea I got was to use fire because I thought lions were scared of fire .
# Actual:  And first first first first first .
#
#
# Expected:  As you can see the bulbs face outside because that s where the lions come from .
# Actual:  You can see see it .
#
#
# Expected:  So I put the lights . You can see at the back those are the lion lights .
# Actual:  So I these these these these these these these .
#
#
# Expected:  I got a chance to come by plane for my first time for TED .
# Actual:  I ve got .
#
#
# Expected:  I was trying to trick the lions into thinking that I was standing near the .
# Actual:  I want to to the the the .
#
#
# Expected:  And a second idea I got was to use a .
# Actual:  So there s the first .
#
#
# Expected:  And I got a switch where I can switch on the lights on and off .
# Actual:  And I had to be . . .
#
#
# Expected:  So you got this scholarship . Yep .
# Actual:  So you you you you get out to the time .
#
#
# Expected:  So I didn t give up . I continued .
# Actual:  But I don t have no much much not not .
#
#
# Expected:  So he jumps in and kills the animals .
# Actual:  So they did them .
#
#
# Expected:  And I discovered that lions are afraid of a moving light .
# Actual:  And I started to to to . . .
#
#
# Expected:  And that s how it looks to lions when they come at night .
# Actual:  And when it was to to to .
#
#
# Expected:  You re working on other electrical inventions .
# Actual:  You you
#
#
# Expected:  And that s a small torch from a broken flashlight .
# Actual:  The is the the .
#
#
# Expected:  And my neighboring homes heard about this idea .
# Actual:  My mother .
#
#
# Expected:  One of them was this grandmother .
# Actual:  And these are them in them .
#
#
# Expected:  And the indicator box makes the lights flash .
# Actual:  The was .
#
#
# Expected:  So I had an idea .
# Actual:  So I had a lot of I have .
#
#
# Expected:  What s the next one on your list ?
# Actual:  You your your .
#
#
# Expected:  And here I am today .
# Actual:  I I I I I I I
#
#
# Expected:  So I set up everything .
# Actual:  All all all all do you do .
#
#
# Expected:  Thanks .
# Actual:  .
#
#
# Expected:  But lions are very clever .
# Actual:  But they re very very very very very
#
#
# Expected:  And I said Yes .
# Actual:  And I I to to .
#
#
# Expected:  The city came down on me and basically gave me a citation saying that I had to remove my garden which this citation was turning into a warrant .
# Actual:  The me .
#
#
# Expected:  But I know electric fences are already invented but I want to make mine .
# Actual:  I know I know I know I know
#
#
# Expected:  My next invention is I want to make an electric fence . Electric fence ?
# Actual:  Now my my my .
#
#
# Expected:  Plus I got tired of driving minutes round trip to get an apple that wasn t with pesticides .
# Actual:  So I I I I I
#
#
# Expected:  A warrant for planting food on a piece of land that you could care less about ?
# Actual:  It s not .
#
#
# Expected:  This is South Central liquor stores fast food vacant lots .
# Actual:  This is the the the the the the
#
#
# Expected:  So what I did I planted a food forest in front of my house .
# Actual:  So I did me for this .
#
#
# Expected:  We re going to cheer you on every step of the way my friend .
# Actual:  So you you you you you you you you you you you
#
#
# Expected:  In the trenches . Richard you are something else .
# Actual:  It is is it be .
#
#
# Expected:  Liquor stores fast food vacant lots .
# Actual:  .
#
#
# Expected:  People are dying from diseases in South Central Los Angeles .
# Actual:  The in the in the .
#
#
# Expected:  And I was like Cool . Bring it .
# Actual:  And I I going to
#
#
# Expected:  Thank you so much . Thank you .
# Actual:  Thank you very much much much .
#
#
# Expected:  I see wheelchairs bought and sold like used cars .
# Actual:  I like like like like like like like like like like like like .
#
#
# Expected:  I see dialysis centers popping up like Starbucks .
# Actual:  I see that the the the the the the . . .
#
#
# Expected:  Food is the problem and food is the solution .
# Actual:  The is is the
#
#
# Expected:  Funny thing is the drive are killing more people than the drive .
# Actual:  And that is something things for this things .
#
#
# Expected:  It was on a strip of land that we call a .
# Actual:  It s called us for us .
#
#
# Expected:  And I m like Come on really ?
# Actual:  I I I
#
#
# Expected:  And this is how I decided to maintain it .
# Actual:  And why why why I I I ? ?
#
#
# Expected:  We had a victory on our hands .
# Actual:  We our our our our our . .
#
#
# Expected:  So I figured that the problem is the solution .
# Actual:  And I ve never have no much much the problem .
#
#
# Expected:  This is South Los Angeles .
# Actual:  This is the the the .
#
#
# Expected:  And I figured this has to stop .
# Actual:  I I t want to want to want to .
#
#
# Expected:  It s feet by feet .
# Actual:  percent .
#
#
# Expected:  But you have to maintain it .
# Actual:  But people people have to be people .
#
#
# Expected:  Because this time it wasn t coming up .
# Actual:  Because there are all much ?
#
#
# Expected:  I live in South Central .
# Actual:  I live in the life in the life .
#
#
# Expected:  I got tired of seeing this happening .
# Actual:  And I ve been these these these these .
#
#
# Expected:  Thing is it s owned by the city .
# Actual:  The the the the the . . .
#
#
# Expected:  And then somebody complained .
# Actual:  But people people be not be .
#
#
# Expected:  And the garden it was beautiful .
# Actual:  It is very very very .
#
#
# Expected:  And I refuse to be a part of this manufactured reality that was manufactured for me by some other people and I m manufacturing my own reality .
# Actual:  And I was to to be . . .
#
#
# Expected:  Just like a graffiti artist where they walls me I beautiful lawns .
# Actual:  It s like a a like the the .
#
#
# Expected:  I use the garden the soil like it s a piece of cloth and the plants and the trees that s my for that cloth .
# Actual:  And I was the with with the . .
#
#
# Expected:  I want them to take it but at the same time I want them to take back their health .
# Actual:  I want to to to people people . .
#
#
# Expected:  I have witnessed my garden become a tool for the education a tool for the transformation of my neighborhood .
# Actual:  I I I I I I .
#
#
# Expected:  There s another time when I put a garden in this homeless shelter in downtown Los Angeles .
# Actual:  And I I I I I I I
#
#
# Expected:  My even called in and said how they endorse and love what we re doing .
# Actual:  They had to to to a .
#
#
# Expected:  You just couldn t imagine how amazing a sunflower is and how it affects people .
# Actual:  You can t you you .
#
#
# Expected:  And I m like Hell no I ain t afraid they re gonna steal it .
# Actual:  And I said
#
#
# Expected:  It s my gospel when I m telling people grow your own food .
# Actual:  That is my my .
#
#
# Expected:  You d be surprised what the soil could do if you let it be your canvas .
# Actual:  You you be be be a the of .
#
#
# Expected:  I mean come on why wouldn t they ?
# Actual:  And what is is I mean it s .
#
#
# Expected:  That s enough space to plant million tomato plants .
# Actual:  There have a have a a . .
#
#
# Expected:  When one dollar s worth of green beans will give you dollars worth of produce .
# Actual:  for a .
#
#
# Expected:  L . leads the United States in vacant lots that the city actually owns .
# Actual:  It was all the .
#
#
# Expected:  See I have a legacy in South Central .
# Actual:  Audience .
#
#
# Expected:  I grew up there . I raised my sons there .
# Actual:  I was in the the . .
#
#
# Expected:  Gardening is my graffiti . I grow my art .
# Actual:  I I I I I I I
#
#
# Expected:  Growing one plant will give you seeds .
# Actual:  It can be be can can be can be . .
#
#
# Expected:  See I m an artist .
# Actual:  Look at a .
#
#
# Expected:  To change the community you have to change the composition of the soil .
# Actual:  It s to to to .
#
#
# Expected:  That s why it s on the street .
# Actual:  And it is is .
#
#
# Expected:  You d be surprised how kids are affected by this .
# Actual:  You you be your children for your children .
#
#
# Expected:  They own square miles of vacant lots .
# Actual:  It s . . .
#
#
# Expected:  Why in the hell would they not okay this ?
# Actual:  And they do it ? ?
#
#
# Expected:  Growing your own food is like printing your own money .
# Actual:  And they have be be . .
#
#
# Expected:  That s Central Parks .
# Actual:  That s the . . .
#
#
# Expected:  Plus you get strawberries .
# Actual:  And you you you you you you have you have you .
#
#
# Expected:  This is on the street for a reason .
# Actual:  This is the the the the . .
#
#
# Expected:  That s the whole idea .
# Actual:  That it s to want to want to want to want .
#
#
# Expected:  So what happened ?
# Actual:  And what ? ? ? ? ? ?
#
#
# Expected:  We are the soil .
# Actual:  We re the the .
#
#
# Expected:  It s a small fishing town in Prefecture about people one of the first that was hit by the wave .
# Actual:  That s the the .
#
#
# Expected:  On March I watched from home as the rest of the world did as the tragic events unfolded in Japan .
# Actual:  Two years .
#
#
# Expected:  The waters here have been recorded at reaching over meters in height and traveled over two miles inland .
# Actual:  The was the the .
#
#
# Expected:  We ve had like people come to our dig ins and participate and it s all volunteers .
# Actual:  We have have have have a year .
#
#
# Expected:  If you want to meet with me come to the garden with your shovel so we can plant some shit .
# Actual:  If I me me me .
#
#
# Expected:  We cleaned schools . We de and gutted homes ready for renovation and rehabilitation .
# Actual:  We have our kids for our children for our own .
#
#
# Expected:  If they grow tomatoes they eat tomatoes .
# Actual:  .
#
#
# Expected:  Before March I was a photographic based in New York City .
# Actual:  Two years .
#
#
# Expected:  I want to plant a whole block of gardens where people can share in the food in the same block .
# Actual:  I want to want to .
#
#
# Expected:  So what I want to do here we gotta make this sexy .
# Actual:  So I want to do it do that do do .
#
#
# Expected:  but if we don t change the composition of the soil we will never do this .
# Actual:  But if we don t we do it ?
#
#
# Expected:  Now this is one of my plans . This is what I want to do .
# Actual:  That is me me me today today today .
#
#
# Expected:  So I want us all to become gardeners .
# Actual:  And we want to be our our . we we .
#
#
# Expected:  The funny thing about sustainability you have to sustain it .
# Actual:  It s a . .
#
#
# Expected:  I want to take shipping containers and turn them into healthy cafes .
# Actual:  I want to want to .
#
#
# Expected:  If kids grow kale kids eat kale .
# Actual:  And they have a to for their .
#
#
# Expected:  I m not talking about no free shit because free is not sustainable .
# Actual:  I I to to to for a for .
#
#
# Expected:  If you ain t a gardener you ain t .
# Actual:  And if you have a be a .
#
#
# Expected:  So Green Grounds has gone on to plant maybe gardens .
# Actual:  The started started to be started to the time .
#
#
# Expected:  And when we do this who knows ?
# Actual:  And do this do this do this ?
#
#
# Expected:  On May the th I made my way to the town of .
# Actual:  Two months .
#
#
# Expected:  These are the guys they helped me unload the truck .
# Actual:  These were these .
#
#
# Expected:  As you can imagine the town had been devastated .
# Actual:  You can can
#
#
# Expected:  Get with your shovel okay ?
# Actual:  The just a a . . .
#
#
# Expected:  Thank you .
# Actual:  .
#
#
# Expected:  We re pale gray creatures .
# Actual:  We re not to t to . .
#
#
# Expected:  We pulled debris from canals and ditches .
# Actual:  We have our the the the the the the the .
#
#
# Expected:  We might produce the next George Washington Carver .
# Actual:  The .
#
#
# Expected:  And let that be your weapon of choice .
# Actual:  Let you you you you you you you you you
#
#
# Expected:  We gotta flip the script on what a is .
# Actual:  We re to to to to .
#
#
# Expected:  Peace . Thank you .
# Actual:  The next .
#
#
# Expected:  Now don t get me wrong .
# Actual:  .
#
#
# ...
# Actual:  is in the .
#
#
# Expected:  Now I live in New Orleans and I am in love with New Orleans .
# Actual:  I was in in the time .
#
#
# Expected:  And I d like to share a few things that people wrote on this wall .
# Actual:  And I want to you you you you want you want you want to you ?
#
#
# Expected:  Before I die I want to be tried for piracy .
# Actual:  And in the . .
#
#
# Expected:  Before I die I want to sing for millions .
# Actual:  And in the . .
#
#
# Expected:  But I struggle to maintain this perspective in my daily life .
# Actual:  But I I really was very much much much much .
#
#
# Expected:  Before I die I want to the International Date Line .
# Actual:  And in the . .
#
#
# Expected:  Before I die I want to be completely myself .
# Actual:  And in the . .
#
#
# Expected:  In I lost someone I loved very much .
# Actual:  .
#
#
# Expected:  Before I die I want to be someone s cavalry .
# Actual:  And in the . .
#
#
# Expected:  We need to work with governments in regional levels .
# Actual:  We need to to and with with .
#
#
# Expected:  Before I die I want to live off the grid .
# Actual:  And in the . .
#
#
# Expected:  Before I die I want to hold her one more time .
# Actual:  And in the . .
#
#
# Expected:  Before I die I want to plant a tree .
# Actual:  And in the . .
#
#
# Expected:  We re working with local communities .
# Actual:  We re our with our . . .
#
#
# Expected:  It s about knowing you re not alone .
# Actual:  That it s really to be .
#
#
# Expected:  Thank you very much .
# Actual:  Thank you very much .
#
#
# Expected:  They are bird blending machines .
# Actual:  They re like the the the .
#
#
# Expected:  When my hand slips I suddenly remember a miner I had met days before who had lost his grip and fell countless feet down that shaft .
# Actual:  My my my . .
#
#
# Expected:  There were no breaks for food no water breaks and the severe dehydration made pretty much inconsequential .
# Actual:  No no no no .
#
#
# Expected:  I hear voices talking but mostly the shaft is this of men coughing and stone being broken with primitive tools .
# Actual:  I I people people people people people .
#
#
# Expected:  I d have to rely on Free the Slaves to work within the system for their liberation and I trusted that they would .
# Actual:  I don t t want to want to be . . .
#
#
# Expected:  Two of the most valuable things we have are time and our relationships with other people .
# Actual:  We have our . . . .
#
#
# Expected:  That s double the amount of people taken from Africa during the entire trans Atlantic slave trade .
# Actual:  The is is is the the is .
#
#
# Expected:  A hundred and fifty years ago an agricultural slave cost about three times the annual salary of an American worker .
# Actual:  years ago ago ago ago ago .
#
#
# Expected:  Slavery exists everywhere nearly in the world and yet it is illegal everywhere in the world .
# Actual:  The is of of the .
#
#
# Expected:  I got to climb out of that hole and I got to go home but they likely never will because they re trapped in slavery .
# Actual:  And I ve got my . .
#
#
# Expected:  Yet today entire families can be enslaved for generations over a debt as small as .
# Actual:  But today today .
#
#
# Expected:  slavery generates profits of more than billion worldwide each year .
# Actual:  And this was a . .
#
#
# Expected:  So pervasive was the heat and the dust that my camera became too hot to even touch and ceased working .
# Actual:  And there is very very very .
#
#
# Expected:  This strange and awesome sight was like walking into ancient Egypt or Dante s Inferno .
# Actual:  And are very very very very very very very . .
#
#
# Expected:  As for me I d have to wait until I got home to really feel my heartbreak .
# Actual:  I m like to .
#
#
# Expected:  I could get them in a worse situation than they were already in .
# Actual:  And my was my my my .
#
#
# Expected:  The air is thick with heat and dust and it s hard to breathe .
# Actual:  . .
#
#
# Expected:  But this time I would see the skeletons hidden in the closet .
# Actual:  But it .
#
#
# Expected:  A conservative estimate tells us there are more than million people enslaved in the world today .
# Actual:  The s . .
#
#
# Expected:  It s about understanding our neighbors in new and enlightening ways .
# Actual:  Let s us us with us .
#
#
# Expected:  Thinking about death clarifies your life .
# Actual:  The would to to be to to . .
#
#
# Expected:  I m feet down an illegal mine shaft in Ghana .
# Actual:  I was in the the the . .
#
#
# Expected:  Thus began my journey into modern day slavery .
# Actual:  So I I I I I I
#
#
# Expected:  Some I even considered like my second home .
# Actual:  I ve also I I I I .
#
#
# Expected:  I couldn t give them money nothing .
# Actual:  I can them them them them for them for them for them .
#
#
# Expected:  In India and Nepal I was introduced to the brick .
# Actual:  In the in the in . .
#
#
# Expected:  It s difficult to witness something so overwhelming .
# Actual:  And this was the the . . .
#
#
# Expected:  I couldn t offer them any direct help .
# Actual:  I I to to to you you you .
#
#
# Expected:  Oddly I had been to many of these places before .
# Actual:  The .
#
#
# Expected:  That equates to about in today s money .
# Actual:  It s a very . .
#
#
# Expected:  Thank you .
# Actual:  .
#
#
# Expected:  I wasn t a citizen of that country .
# Actual:  I m not not the the the the the
#
#
# Expected:  Thank you .
# Actual:  Thank you .
#
#
# Expected:  It s estimated that more than children are enslaved on Lake Volta the largest man made lake in the world .
# Actual:  .
#
#
# Expected:  Recently the New York Times reported that between and American children are sold into sex slavery every year .
# Actual:  The in in the in the in the the .
#
#
# Expected:  He was trembling when our boat approached frightened it would run over his tiny canoe .
# Actual:  And our our our our
#
#
# Expected:  I saw what seemed to be a family fishing on a boat two older brothers some younger kids makes sense right ?
# Actual:  And I was it is it .
#
#
# Expected:  We hope still though that we could leave this house someday and go someplace else where we actually get paid for our .
# Actual:  We I to to to we would we .
#
#
# Expected:  The dyed black hands are the father while the blue and red hands are his sons .
# Actual:  That was was a . . .
#
#
# Expected:  They ushered me down a narrow set of stairs that led to this dirty fluorescent lit basement .
# Actual:  They me me me me .
#
#
# Expected:  Each cubicle is dark and identified with a painted number on the wall and partitioned by plywood and a curtain .
# Actual:  And all all all all all all .
#
#
# Expected:  How can we affect something so insidious yet so pervasive ?
# Actual:  How do do do do do do ? do do ? do ? do ? do ? ?
#
#
# Expected:  When these villagers claimed their freedom the burned down all of their houses .
# Actual:  And if those are
#
#
# Expected:  The workers here often endure tragic sexual abuse at the hands of their customers .
# Actual:  And here on the time .
#
#
# Expected:  I visited villages in India where entire families were enslaved in the silk trade .
# Actual:  I was a to in a the in . . .
#
#
# Expected:  Tens of hundreds of people are enslaved in agriculture in restaurants in domestic servitude and the list can go on .
# Actual:  of years .
#
#
# Expected:  In Kathmandu I was escorted by women who had previously been sex slaves themselves .
# Actual:  In the . .
#
#
# Expected:  The textile industry is another one we often think of when we hear about slave labor .
# Actual:  .
#
#
# Expected:  Cabin restaurants as they re known in the trade are venues for forced prostitution .
# Actual:  The is the the the the the the
#
#
# Expected:  It s all around us . We just don t see it .
# Actual:  So these things are happening in this things .
#
#
# Expected:  When we first arrived I went to have a quick look .
# Actual:  We re in them here .
#
#
# Expected:  For as long as he can recall he s been forced to work on the lake .
# Actual:  And he started from the time from the time .
#
#
# Expected:  I had only one way out the stairs from where I d come in .
# Actual:  So here is the the the .
#
#
# Expected:  This is a family portrait .
# Actual:  That s the .
#
#
# Expected:  We have no freedom they said .
# Actual:  We have no .
#
#
# Expected:  Wrong . They were all enslaved .
# Actual:  They they they they they they they .
#
#
# Expected:  He was petrified he would be knocked in the water .
# Actual:  It would be be be be be going to be .
#
#
# Expected:  My interpreter told me their stories .
# Actual:  I me me them them them they they tell them .
#
#
# Expected:  This young child is eight years old .
# Actual:  This is the the .
#
#
# Expected:  This wasn t a brothel per se .
# Actual:  It s not not not not
#
#
# Expected:  It was more like a restaurant .
# Actual:  It s like it .
#
#
# Expected:  There were no windows large enough to climb through .
# Actual:  It is no much have a . .
#
#
# Expected:  Many of them drown .
# Actual:  Some of people people who are a lot .
#
#
# Expected:  They have nothing to compare it to .
# Actual:  There is no .
#
#
# Expected:  There were no back doors .
# Actual:  There s no no .
#
#
# Expected:  On top of that has tuberculosis yet he s still forced to work day in and day out in that mine shaft .
# Actual:  There there are not have to be . .
#
#
# Expected:  Then he pointed toward this barely visible footpath and said This is the path this is the path . Go .
# Actual:  And he he he was the the the
#
#
# Expected:  I remember looking into their tired eyes for many of them had been underground for hours .
# Actual:  I have them them them they was all the .
#
#
# Expected:  This is . When his father died his uncle trafficked him to work with him in the mines .
# Actual:  That s the .
#
#
# Expected:  I truly believe if we can see one another as fellow human beings then it becomes very difficult to tolerate atrocities like slavery .
# Actual:  I I believe that I believe it s really .
#
#
# Expected:  Who will he become because someone took a stand and made a difference in his life ?
# Actual:  And that it is not not not the much not not .
#
#
# Expected:  Many women had children strapped to their backs while they were for gold wading in water poisoned by mercury .
# Actual:  Some of them to be a a . . . .
#
#
# Expected:  When his uncle died inherited his uncle s debt which further forced him into being enslaved in the mines .
# Actual:  And he was a .
#
#
# Expected:  We delight at ballet and tap dancers you will see later on .
# Actual:  We have to be a the .
#
#
# Expected:  Now that would actually save on a difficult trip to the clinic and what if patients could do that test themselves right ?
# Actual:  That s also be a for .
#
#
# Expected:  I met him at a shelter where Free the Slaves victims of slavery .
# Actual:  And he s in the .
#
#
# Expected:  Takes about by the way in the neurologist s clinic to do it .
# Actual:  The one of .
#
#
# Expected:  So I am going to give you some attempt today to try and explain to you what I do .
# Actual:  So I I I
#
#
# Expected:  At the end of the road he urged us out of the car and told the driver to quickly leave .
# Actual:  It s the the the the the the . . . .
#
#
# Expected:  And it s important to note that these nets weigh more than a thousand pounds when they re full of fish .
# Actual:  And know to know .
#
#
# Expected:  These miners are enslaved in a mine shaft in another part of Ghana .
# Actual:  These are are of of . .
#
#
# Expected:  He told us to follow him down a dirt road into the jungle .
# Actual:  And he s us us us us us us .
#
#
# Expected:  They knew their image would be seen by you out in the world .
# Actual:  They know these these these these .
#
#
# Expected:  So great progress and treatment has been made over the years .
# Actual:  And he was to . .
#
#
# Expected:  I want to shine a light on slavery .
# Actual:  And let me we want to give us for us for us .
#
#
# Expected:  So dancing is one of the most human of activities .
# Actual:  Oh .
#
#
# Expected:  No expensive staff time required .
# Actual:  It s to be a to . . .
#
#
# Expected:  Kofi was rescued from a fishing village .
# Actual:  And he was a the the .
#
#
# Expected:  Kofi is the embodiment of possibility .
# Actual:  .
#
#
# Expected:  When they came out of the shaft they were soaking wet from their own sweat .
# Actual:  So they get to the the the the
#
#
# Expected:  But what if patients could do this test at home ?
# Actual:  But if if can be can be a .
#
#
# Expected:  in the cold windy night .
# Actual:  It s in .
#
#
# Expected:  All of them are victim to injury illness and violence .
# Actual:  They are all the . .
#
#
# Expected:  I want to introduce you to Kofi .
# Actual:  Thank you you you you here here here here here here here .
#
#
# Expected:  Mercury is used in the extraction process .
# Actual:  It are the for the for the . . .
#
#
# Expected:  No one knows what the hell we do .
# Actual:  And it s not it s it s .
#
#
# Expected:  Thank you very much .
# Actual:  Thank you .
#
#
# Expected:  And they re both accurate . Okay but in addition voice based tests are non expert .
# Actual:  They have have be . . .
#
#
# Expected:  So taking the first steps towards this today we re launching the Parkinson s Voice Initiative .
# Actual:  So so .
#
#
# Expected:  There were no art directors no no chance for not even any regard for lighting .
# Actual:  There s no no .
#
#
# Expected:  We have the opportunity to start to search for the early biomarkers of the disease before it s too late .
# Actual:  We have to to a a of . . . .
#
#
# Expected:  The neurologist s test is non invasive . They both use existing infrastructure .
# Actual:  The is a . .
#
#
# Expected:  So on the bottom trace you can see an example of irregular vocal fold tremor .
# Actual:  And can you see it ? ?
#
#
# Expected:  The speech actually becomes quieter and more after a while and that s one of the example symptoms of it .
# Actual:  It would be to be .
#
#
# Expected:  When something becomes ultra low cost it becomes massively scalable .
# Actual:  And it is the . .
#
#
# Expected:  We have local numbers accessible to three quarters of a billion people on the planet .
# Actual:  We our our our our our .
#
#
# Expected:  You see some people may not do it . They may not get through it .
# Actual:  And know to know .
#
#
# Expected:  In fact most of them were taken by random tourists .
# Actual:  It s actually .
#
#
# Expected:  I mean just think how long it takes a child to learn to speak .
# Actual:  It can can .
#
#
# Expected:  nine . Well that s an improvement .
# Actual:  .
#
#
# Expected:  And like ballet it takes an extraordinary level of training .
# Actual:  It was like like like like like like like like like like .
#
#
# Expected:  You don t have to design a whole new set of hospitals to do it .
# Actual:  You have to to to you you you .
#
#
# Expected:  They re ultra low cost and we all know what happens .
# Actual:  It s very .
#
#
# Expected:  So here are some amazing goals that I think we can deal with now .
# Actual:  I m now now now now now now now today today today today today today today today today today today today today today ?
#
#
# Expected:  We can do high frequency monitoring to get objective data .
# Actual:  We can do this for this for this .
#
#
# Expected:  They re high speed take about seconds at most .
# Actual:  It s also very much . .
#
#
# Expected:  So here we have a video of the vibrating vocal folds .
# Actual:  I m here here .
#
#
# Expected:  What are you going to get out of those samples ?
# Actual:  You want to to to from the from .
#
#
# Expected:  So you re percent accurate right now ?
# Actual:  So you have you have have have have have a lot for .
#
#
# Expected:  Thanks so much . Max Little everybody .
# Actual:  Thank you very much .
#
#
# Expected:  We see vocal tremor weakness and rigidity .
# Actual:  The .
#
#
# Expected:  We can reduce logistical difficulties with patients .
# Actual:  We can have to and and .
#
#
# Expected:  No need to go to the clinic for a routine .
# Actual:  I have to to to a a a . .
#
#
# Expected:  That means they can be self administered .
# Actual:  This is the the the the the . .
#
#
# Expected:  We see all the same symptoms .
# Actual:  We re like like that we re like like .
#
#
# Expected:  It s much better than that .
# Actual:  It s still still still be still .
#
#
# Expected:  Thanks Tom .
# Actual:  Thank you .
#
#
# Expected:  Thank you .
# Actual:  Thank you .
#
#
# Expected:  Absolutely .
# Actual:  That s the .

# %%
evaluate_bleu(decoded, actual)
# Out:
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# 1.1691207505793362
